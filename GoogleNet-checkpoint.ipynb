# %%
import os
os.chdir("C:\\COLON_CANCER DATASET")

# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks, regularizers
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


X_train = np.load("CONCATENATED_FEATURES_TRAIN_GoogleNet.npy")  
y_train = np.load("Training_labels.npy")    
X_val = np.load("CONCATENATED_FEATURES_VALIDATE_GoogleNet.npy")
y_val = np.load("Validation_labels.npy")

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")


num_classes = 5  
y_train = to_categorical(y_train, num_classes=num_classes)
y_val = to_categorical(y_val, num_classes=num_classes)


def build_mlp(input_shape=(2048,), num_classes=5):
    inputs = layers.Input(shape=input_shape)
    x = layers.Dense(1024, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(inputs)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(512, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(256, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.55)(x)
    
    x = layers.Dense(128, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(64, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(32, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.45)(x)

    x = layers.Dense(16, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.35)(x)
    
    outputs = layers.Dense(num_classes, activation='softmax')(x)  
    
    model = models.Model(inputs, outputs)
    optimizer = optimizers.AdamW(learning_rate=0.01, weight_decay=1e-4, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

if __name__ == "__main__":
    model = build_mlp()
    model.summary()
    
    lr_scheduler = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[lr_scheduler])
    
    
    log_data = []
    for epoch in range(0, len(history.history['accuracy']), 10):
        log_data.append([
            epoch,
            history.history['accuracy'][epoch],
            history.history['loss'][epoch],
            history.history['val_accuracy'][epoch],
            history.history['val_loss'][epoch]
        ])

    if (len(history.history['accuracy']) - 1) % 10 != 0:
        last_epoch = len(history.history['accuracy']) - 1
        log_data.append([
            last_epoch,
            history.history['accuracy'][last_epoch],
            history.history['loss'][last_epoch],
            history.history['val_accuracy'][last_epoch],
            history.history['val_loss'][last_epoch]
        ])
    
   
    log_df = pd.DataFrame(log_data, columns=['Epoch', 'Training Accuracy', 'Training Loss', 'Validation Accuracy', 'Validation Loss'])
    print(log_df.to_string(index=False))
# Out:
# X_train shape: (3150, 2048), y_train shape: (3150,)
# X_val shape: (449, 2048), y_val shape: (449,)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_14 (ReLU)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_15 (ReLU)                      │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_16               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_16 (ReLU)                      │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_17               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_17 (ReLU)                      │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_17 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_18               │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_18 (ReLU)                      │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_18 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_19               │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_19 (ReLU)                      │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_19 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_20               │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_20 (ReLU)                      │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 5)                   │              85 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,806,277 (10.71 MB)
#  Trainable params: 2,802,213 (10.69 MB)
#  Non-trainable params: 4,064 (15.88 KB)
# Epoch 1/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.2464 - loss: 2.5474 - val_accuracy: 0.4388 - val_loss: 2.1288 - learning_rate: 0.0100
# Epoch 2/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.5209 - loss: 2.0866 - val_accuracy: 0.6971 - val_loss: 1.8432 - learning_rate: 0.0100
# Epoch 3/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.6481 - loss: 2.0808 - val_accuracy: 0.6904 - val_loss: 1.9485 - learning_rate: 0.0100
# Epoch 4/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.6859 - loss: 2.0591 - val_accuracy: 0.7261 - val_loss: 2.0226 - learning_rate: 0.0100
# Epoch 5/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.6731 - loss: 2.2043 - val_accuracy: 0.8241 - val_loss: 1.7772 - learning_rate: 0.0100
# Epoch 6/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.7134 - loss: 2.1037 - val_accuracy: 0.7528 - val_loss: 1.8052 - learning_rate: 0.0100
# Epoch 7/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7231 - loss: 2.0078 - val_accuracy: 0.8931 - val_loss: 1.7996 - learning_rate: 0.0100
# Epoch 8/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7581 - loss: 2.1907 - val_accuracy: 0.8953 - val_loss: 1.7797 - learning_rate: 0.0100
# Epoch 9/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7739 - loss: 2.2759 - val_accuracy: 0.9265 - val_loss: 1.6360 - learning_rate: 0.0100
# Epoch 10/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8117 - loss: 2.0082 - val_accuracy: 0.8597 - val_loss: 2.0525 - learning_rate: 0.0100
# Epoch 11/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7932 - loss: 2.3147 - val_accuracy: 0.8842 - val_loss: 1.8225 - learning_rate: 0.0100
# Epoch 12/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8092 - loss: 2.1290 - val_accuracy: 0.9042 - val_loss: 1.8249 - learning_rate: 0.0100
# Epoch 13/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8231 - loss: 2.0154 - val_accuracy: 0.9109 - val_loss: 1.7119 - learning_rate: 0.0100
# Epoch 14/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7896 - loss: 2.0900 - val_accuracy: 0.8931 - val_loss: 2.0426 - learning_rate: 0.0100
# Epoch 15/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8406 - loss: 2.1212 - val_accuracy: 0.9042 - val_loss: 1.5416 - learning_rate: 0.0050
# Epoch 16/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8430 - loss: 1.7600 - val_accuracy: 0.9488 - val_loss: 1.2921 - learning_rate: 0.0050
# Epoch 17/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8600 - loss: 1.6173 - val_accuracy: 0.8864 - val_loss: 1.4460 - learning_rate: 0.0050
# Epoch 18/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8358 - loss: 1.6536 - val_accuracy: 0.9577 - val_loss: 1.2261 - learning_rate: 0.0050
# Epoch 19/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8593 - loss: 1.5556 - val_accuracy: 0.9332 - val_loss: 1.2653 - learning_rate: 0.0050
# Epoch 20/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8707 - loss: 1.5232 - val_accuracy: 0.9488 - val_loss: 1.1899 - learning_rate: 0.0050
# Epoch 21/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8580 - loss: 1.5427 - val_accuracy: 0.9399 - val_loss: 1.2218 - learning_rate: 0.0050
# Epoch 22/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8468 - loss: 1.5502 - val_accuracy: 0.9532 - val_loss: 1.2013 - learning_rate: 0.0050
# Epoch 23/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8687 - loss: 1.5354 - val_accuracy: 0.9287 - val_loss: 1.3410 - learning_rate: 0.0050
# Epoch 24/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.8622 - loss: 1.6043 - val_accuracy: 0.9332 - val_loss: 1.4036 - learning_rate: 0.0050
# Epoch 25/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8743 - loss: 1.5967 - val_accuracy: 0.9243 - val_loss: 1.4263 - learning_rate: 0.0050
# Epoch 26/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8739 - loss: 1.5757 - val_accuracy: 0.9555 - val_loss: 1.2077 - learning_rate: 0.0025
# Epoch 27/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9006 - loss: 1.3780 - val_accuracy: 0.9332 - val_loss: 1.1412 - learning_rate: 0.0025
# Epoch 28/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9000 - loss: 1.2320 - val_accuracy: 0.9621 - val_loss: 0.9790 - learning_rate: 0.0025
# Epoch 29/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8885 - loss: 1.2118 - val_accuracy: 0.9710 - val_loss: 0.8926 - learning_rate: 0.0025
# Epoch 30/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9066 - loss: 1.1199 - val_accuracy: 0.9733 - val_loss: 0.8551 - learning_rate: 0.0025
# Epoch 31/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8762 - loss: 1.2175 - val_accuracy: 0.9310 - val_loss: 1.0026 - learning_rate: 0.0025
# Epoch 32/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8988 - loss: 1.1246 - val_accuracy: 0.9265 - val_loss: 1.0250 - learning_rate: 0.0025
# Epoch 33/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9084 - loss: 1.0707 - val_accuracy: 0.9532 - val_loss: 0.8990 - learning_rate: 0.0025
# Epoch 34/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9043 - loss: 1.0942 - val_accuracy: 0.9354 - val_loss: 0.9789 - learning_rate: 0.0025
# Epoch 35/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9010 - loss: 1.1447 - val_accuracy: 0.9688 - val_loss: 0.8450 - learning_rate: 0.0025
# Epoch 36/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9082 - loss: 1.0724 - val_accuracy: 0.9644 - val_loss: 0.8402 - learning_rate: 0.0025
# Epoch 37/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9159 - loss: 1.0782 - val_accuracy: 0.9087 - val_loss: 1.0931 - learning_rate: 0.0025
# Epoch 38/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9120 - loss: 1.0419 - val_accuracy: 0.9443 - val_loss: 0.8763 - learning_rate: 0.0025
# Epoch 39/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9175 - loss: 1.0253 - val_accuracy: 0.9532 - val_loss: 0.8735 - learning_rate: 0.0025
# Epoch 40/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8946 - loss: 1.0718 - val_accuracy: 0.9354 - val_loss: 0.9199 - learning_rate: 0.0025
# Epoch 41/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9139 - loss: 1.0077 - val_accuracy: 0.9644 - val_loss: 0.8080 - learning_rate: 0.0025
# Epoch 42/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9145 - loss: 1.0324 - val_accuracy: 0.9644 - val_loss: 0.8296 - learning_rate: 0.0025
# Epoch 43/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9098 - loss: 1.0356 - val_accuracy: 0.9666 - val_loss: 0.8131 - learning_rate: 0.0025
# Epoch 44/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9104 - loss: 1.0433 - val_accuracy: 0.9777 - val_loss: 0.7541 - learning_rate: 0.0025
# Epoch 45/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9288 - loss: 0.9582 - val_accuracy: 0.9621 - val_loss: 0.7958 - learning_rate: 0.0025
# Epoch 46/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9078 - loss: 0.9834 - val_accuracy: 0.9644 - val_loss: 0.7842 - learning_rate: 0.0025
# Epoch 47/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9275 - loss: 0.9694 - val_accuracy: 0.9287 - val_loss: 0.8906 - learning_rate: 0.0025
# Epoch 48/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9065 - loss: 1.0029 - val_accuracy: 0.9733 - val_loss: 0.7900 - learning_rate: 0.0025
# Epoch 49/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9074 - loss: 1.0698 - val_accuracy: 0.9443 - val_loss: 0.8709 - learning_rate: 0.0025
# Epoch 50/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9272 - loss: 0.9482 - val_accuracy: 0.9488 - val_loss: 0.8152 - learning_rate: 0.0012
# Epoch 51/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9320 - loss: 0.9043 - val_accuracy: 0.9755 - val_loss: 0.6923 - learning_rate: 0.0012
# Epoch 52/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9245 - loss: 0.8858 - val_accuracy: 0.9644 - val_loss: 0.7385 - learning_rate: 0.0012
# Epoch 53/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9365 - loss: 0.8191 - val_accuracy: 0.9777 - val_loss: 0.6538 - learning_rate: 0.0012
# Epoch 54/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9439 - loss: 0.7558 - val_accuracy: 0.9710 - val_loss: 0.6548 - learning_rate: 0.0012
# Epoch 55/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9484 - loss: 0.7272 - val_accuracy: 0.9577 - val_loss: 0.6784 - learning_rate: 0.0012
# Epoch 56/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9382 - loss: 0.7819 - val_accuracy: 0.9621 - val_loss: 0.6402 - learning_rate: 0.0012
# Epoch 57/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9330 - loss: 0.7747 - val_accuracy: 0.9621 - val_loss: 0.7284 - learning_rate: 0.0012
# Epoch 58/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9382 - loss: 0.7283 - val_accuracy: 0.9577 - val_loss: 0.6111 - learning_rate: 0.0012
# Epoch 59/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9332 - loss: 0.7346 - val_accuracy: 0.9599 - val_loss: 0.6208 - learning_rate: 0.0012
# Epoch 60/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9448 - loss: 0.6912 - val_accuracy: 0.9688 - val_loss: 0.5878 - learning_rate: 0.0012
# Epoch 61/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9402 - loss: 0.6984 - val_accuracy: 0.9777 - val_loss: 0.5478 - learning_rate: 0.0012
# Epoch 62/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9337 - loss: 0.7282 - val_accuracy: 0.9755 - val_loss: 0.5219 - learning_rate: 0.0012
# Epoch 63/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9469 - loss: 0.6758 - val_accuracy: 0.9666 - val_loss: 0.5590 - learning_rate: 0.0012
# Epoch 64/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9379 - loss: 0.6956 - val_accuracy: 0.9800 - val_loss: 0.5167 - learning_rate: 0.0012
# Epoch 65/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9443 - loss: 0.6359 - val_accuracy: 0.9376 - val_loss: 0.6903 - learning_rate: 0.0012
# Epoch 66/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9195 - loss: 0.7384 - val_accuracy: 0.9733 - val_loss: 0.5233 - learning_rate: 0.0012
# Epoch 67/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9440 - loss: 0.6843 - val_accuracy: 0.9777 - val_loss: 0.5312 - learning_rate: 0.0012
# Epoch 68/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9311 - loss: 0.7029 - val_accuracy: 0.9800 - val_loss: 0.5023 - learning_rate: 0.0012
# Epoch 69/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9433 - loss: 0.6483 - val_accuracy: 0.9710 - val_loss: 0.5352 - learning_rate: 0.0012
# Epoch 70/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9437 - loss: 0.6492 - val_accuracy: 0.9666 - val_loss: 0.5433 - learning_rate: 0.0012
# Epoch 71/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9363 - loss: 0.6641 - val_accuracy: 0.9688 - val_loss: 0.5566 - learning_rate: 0.0012
# Epoch 72/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9510 - loss: 0.6400 - val_accuracy: 0.9710 - val_loss: 0.5815 - learning_rate: 0.0012
# Epoch 73/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9489 - loss: 0.6270 - val_accuracy: 0.9688 - val_loss: 0.5207 - learning_rate: 0.0012
# Epoch 74/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9599 - loss: 0.5822 - val_accuracy: 0.9710 - val_loss: 0.5823 - learning_rate: 6.2500e-04
# Epoch 75/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9588 - loss: 0.5812 - val_accuracy: 0.9710 - val_loss: 0.5203 - learning_rate: 6.2500e-04
# Epoch 76/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9490 - loss: 0.6297 - val_accuracy: 0.9688 - val_loss: 0.5077 - learning_rate: 6.2500e-04
# Epoch 77/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9709 - loss: 0.5045 - val_accuracy: 0.9800 - val_loss: 0.4663 - learning_rate: 6.2500e-04
# Epoch 78/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9604 - loss: 0.5530 - val_accuracy: 0.9844 - val_loss: 0.4231 - learning_rate: 6.2500e-04
# Epoch 79/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9586 - loss: 0.5351 - val_accuracy: 0.9844 - val_loss: 0.4379 - learning_rate: 6.2500e-04
# Epoch 80/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9588 - loss: 0.5488 - val_accuracy: 0.9822 - val_loss: 0.4281 - learning_rate: 6.2500e-04
# Epoch 81/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9565 - loss: 0.5232 - val_accuracy: 0.9911 - val_loss: 0.3874 - learning_rate: 6.2500e-04
# Epoch 82/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9579 - loss: 0.5101 - val_accuracy: 0.9822 - val_loss: 0.4125 - learning_rate: 6.2500e-04
# Epoch 83/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9641 - loss: 0.4823 - val_accuracy: 0.9800 - val_loss: 0.4233 - learning_rate: 6.2500e-04
# Epoch 84/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9524 - loss: 0.5270 - val_accuracy: 0.9733 - val_loss: 0.5021 - learning_rate: 6.2500e-04
# Epoch 85/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9616 - loss: 0.4930 - val_accuracy: 0.9688 - val_loss: 0.4541 - learning_rate: 6.2500e-04
# Epoch 86/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9518 - loss: 0.5261 - val_accuracy: 0.9777 - val_loss: 0.4343 - learning_rate: 6.2500e-04
# Epoch 87/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9647 - loss: 0.4785 - val_accuracy: 0.9733 - val_loss: 0.4235 - learning_rate: 3.1250e-04
# Epoch 88/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9584 - loss: 0.4734 - val_accuracy: 0.9644 - val_loss: 0.5348 - learning_rate: 3.1250e-04
# Epoch 89/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9637 - loss: 0.4625 - val_accuracy: 0.9800 - val_loss: 0.3828 - learning_rate: 3.1250e-04
# Epoch 90/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9606 - loss: 0.4524 - val_accuracy: 0.9599 - val_loss: 0.4636 - learning_rate: 3.1250e-04
# Epoch 91/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9641 - loss: 0.4496 - val_accuracy: 0.9822 - val_loss: 0.4064 - learning_rate: 3.1250e-04
# Epoch 92/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9664 - loss: 0.4369 - val_accuracy: 0.9644 - val_loss: 0.4432 - learning_rate: 3.1250e-04
# Epoch 93/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9599 - loss: 0.4601 - val_accuracy: 0.9644 - val_loss: 0.5183 - learning_rate: 3.1250e-04
# Epoch 94/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9654 - loss: 0.4345 - val_accuracy: 0.9733 - val_loss: 0.4920 - learning_rate: 3.1250e-04
# Epoch 95/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9602 - loss: 0.4506 - val_accuracy: 0.9844 - val_loss: 0.3439 - learning_rate: 1.5625e-04
# Epoch 96/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9653 - loss: 0.4682 - val_accuracy: 0.9911 - val_loss: 0.3362 - learning_rate: 1.5625e-04
# Epoch 97/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9688 - loss: 0.4195 - val_accuracy: 0.9555 - val_loss: 0.5426 - learning_rate: 1.5625e-04
# Epoch 98/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9700 - loss: 0.4205 - val_accuracy: 0.9777 - val_loss: 0.3799 - learning_rate: 1.5625e-04
# Epoch 99/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9757 - loss: 0.3858 - val_accuracy: 0.9911 - val_loss: 0.3268 - learning_rate: 1.5625e-04
# Epoch 100/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9683 - loss: 0.3978 - val_accuracy: 0.9866 - val_loss: 0.3369 - learning_rate: 1.5625e-04
#  Epoch  Training Accuracy  Training Loss  Validation Accuracy  Validation Loss
#      0           0.314603       2.529988             0.438753         2.128844
#     10           0.795873       2.264111             0.884187         1.822520
#     20           0.857778       1.556287             0.939866         1.221795
#     30           0.881905       1.194762             0.930958         1.002630
#     40           0.913651       1.017165             0.964365         0.808001
#     50           0.931111       0.906532             0.975501         0.692313
#     60           0.939365       0.715336             0.977728         0.547757
#     70           0.940317       0.658926             0.968820         0.556572
#     80           0.952064       0.553633             0.991091         0.387432
#     90           0.963492       0.450088             0.982183         0.406396
#     99           0.969524       0.400245             0.986637         0.336936

# %%
import matplotlib.pyplot as plt

model.save("mlp_model_GoogleNet.h5")

print("Model saved successfully!!")

plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy for GoogleNet')
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!!

# %%
import os
import pickle
import numpy as np


directory = "C:\\COLON_CANCER DATASET\\PolypDB\\PolypDB_modality_wise\\AUG_PICS\\Model_Test_Feature_PKLs\\GoogleNet"


modalities = ["bli", "wli", "nbi", "fice", "lci"]


for modality in modalities:
    con_features = []
    count = 0

    for file in os.listdir(directory):
        if modality in file.lower():  
            filename = os.path.join(directory, file)
            count += 1
            with open(filename, 'rb') as f:
                data = pickle.load(f)
                l = len(data)
                con_features.append(data)

    if count > 0:
       
        con_features_arr = np.concatenate(con_features, axis=0)
        con_features_mod = con_features_arr.reshape(count, l)

        
        np.save(f"CONCATENATED_FEATURES_TEST_{modality.upper()}_GoogleNet.npy", con_features_mod)

        print(f"Saved {modality.upper()} test features successfully! Shape: {con_features_mod.shape}")
    else:
        print(f"No files found for {modality.upper()}.")
# Out:
# Saved BLI test features successfully! Shape: (196, 2048)
# Saved WLI test features successfully! Shape: (162, 2048)
# Saved NBI test features successfully! Shape: (180, 2048)
# Saved FICE test features successfully! Shape: (189, 2048)
# Saved LCI test features successfully! Shape: (174, 2048)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, log_loss


model = load_model("mlp_model_GoogleNet.h5")


modalities = ["BLI", "WLI", "FICE", "LCI", "NBI"]
label_order = ["BLI", "FICE", "LCI", "NBI", "WLI"]
label_map = {modality: idx for idx, modality in enumerate(label_order)}


def plot_confusion_matrix(y_true, y_pred, modality):
    cm = confusion_matrix(y_true, y_pred, labels=range(5))
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=label_order, yticklabels=label_order)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix - {modality}")
    plt.show()


l_dense = []


for modality in modalities:
    X_test = np.load(f"CONCATENATED_FEATURES_TEST_{modality}_GoogleNet.npy")
    
   
    modality_label = label_map[modality]
    y_test = np.full(shape=(len(X_test),), fill_value=modality_label)

    num_classes = 5  
    y_test_one_hot = tf.keras.utils.to_categorical(y_test, num_classes=num_classes)

    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test_one_hot, axis=1)

   
    accuracy = accuracy_score(y_true, y_pred)
    logloss = log_loss(y_test_one_hot, y_pred_probs)
    l_dense.append(logloss)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

   
    print(f"Results for {modality}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")
    print(f"Log Loss: {logloss:.4f}")
    print(f"Unique labels in y_test: {np.unique(y_test)}")
    print("-" * 40)

    
    plot_confusion_matrix(y_true, y_pred, modality)


print(f"Average Log_loss for the GoogleNet: {sum(l_dense)/5:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Results for BLI:
# Accuracy: 0.9796
# Precision: 1.0000
# Recall: 0.9796
# F1-score: 0.9897
# Log Loss: 0.1134
# Unique labels in y_test: [0]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for WLI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0007
# Unique labels in y_test: [4]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Results for FICE:
# Accuracy: 0.9947
# Precision: 1.0000
# Recall: 0.9947
# F1-score: 0.9973
# Log Loss: 0.0183
# Unique labels in y_test: [1]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Results for LCI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0012
# Unique labels in y_test: [2]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Results for NBI:
# Accuracy: 0.9944
# Precision: 1.0000
# Recall: 0.9944
# F1-score: 0.9972
# Log Loss: 0.0256
# Unique labels in y_test: [3]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Average Log_loss for the GoogleNet: 0.0318

# %%
import numpy as np
import matplotlib.pyplot as plt


modalities = ["BLI", "WLI", "FICE", "NBI", "LCI"]
models = ["DenseNet201", "VGG16", "VGG19", "ResNet50", "ResNet101", "InceptionV3", "InceptionResNetV2", "GoogleNet"]


accuracy_values = {
    "DenseNet201":       [1.00, 1.00,1.00 ,0.9943 , 0.9944],
    "VGG16":             [0.9949, 0.9938, 1.00, .9770, 1.00],
    "VGG19":             [0.9898, 1.00, 0.9947, 0.9770, 0.9778],
    "ResNet50":          [1.00, 1.00, 1.00, 1.00, 1.00],
    "ResNet101":         [0.9949, 1.00, 1.00, .9943, 1.00],
    "InceptionV3":       [1.00, .8951, 0.9841, 0.9598, 0.9833],
    "InceptionResNetV2": [0.9490, 0.9877, 0.9841, 1.00, 1.00],
    "GoogleNet":         [0.9796, 1.00, 0.9947, 1.00, 0.9944]
}


x = np.arange(len(modalities))
bar_width = 0.1


fig, ax = plt.subplots(figsize=(12, 6))


for i, (model, accuracies) in enumerate(accuracy_values.items()):
    ax.bar(x + i * bar_width, accuracies, width=bar_width, label=model)


ax.set_xticks(x + (bar_width * len(models) / 2))
ax.set_xticklabels(modalities)
ax.set_ylabel("Accuracy")
ax.set_title("Feature Extraction Models Accuracy Across Modalities")
ax.legend(loc="upper left", bbox_to_anchor=(1, 1))


plt.tight_layout()
plt.show()
