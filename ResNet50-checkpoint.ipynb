# %%
import os
os.chdir("C:\\COLON_CANCER DATASET")

# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks, regularizers
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


X_train = np.load("CONCATENATED_FEATURES_TRAIN_Res50.npy")  
y_train = np.load("Training_labels.npy")    
X_val = np.load("CONCATENATED_FEATURES_VALIDATE_Res50.npy")
y_val = np.load("Validation_labels.npy")

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")


num_classes = 5  
y_train = to_categorical(y_train, num_classes=num_classes)
y_val = to_categorical(y_val, num_classes=num_classes)


def build_mlp(input_shape=(2048,), num_classes=5):
    inputs = layers.Input(shape=input_shape)
    x = layers.Dense(1024, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(inputs)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(512, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(256, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.55)(x)
    
    x = layers.Dense(128, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(64, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(32, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.45)(x)

    x = layers.Dense(16, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.35)(x)
    
    outputs = layers.Dense(num_classes, activation='softmax')(x)  
    
    model = models.Model(inputs, outputs)
    optimizer = optimizers.AdamW(learning_rate=0.01, weight_decay=1e-4, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

if __name__ == "__main__":
    model = build_mlp()
    model.summary()
    
    lr_scheduler = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[lr_scheduler])
    
    
    log_data = []
    for epoch in range(0, len(history.history['accuracy']), 10):
        log_data.append([
            epoch,
            history.history['accuracy'][epoch],
            history.history['loss'][epoch],
            history.history['val_accuracy'][epoch],
            history.history['val_loss'][epoch]
        ])

    if (len(history.history['accuracy']) - 1) % 10 != 0:
        last_epoch = len(history.history['accuracy']) - 1
        log_data.append([
            last_epoch,
            history.history['accuracy'][last_epoch],
            history.history['loss'][last_epoch],
            history.history['val_accuracy'][last_epoch],
            history.history['val_loss'][last_epoch]
        ])
    
   
    log_df = pd.DataFrame(log_data, columns=['Epoch', 'Training Accuracy', 'Training Loss', 'Validation Accuracy', 'Validation Loss'])
    print(log_df.to_string(index=False))
# Out:
# X_train shape: (3150, 2048), y_train shape: (3150,)
# X_val shape: (449, 2048), y_val shape: (449,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_2 (ReLU)                       │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_3 (ReLU)                       │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_4 (ReLU)                       │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_5 (ReLU)                       │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_6 (ReLU)                       │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 5)                   │              85 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,806,277 (10.71 MB)
#  Trainable params: 2,802,213 (10.69 MB)
#  Non-trainable params: 4,064 (15.88 KB)
# Epoch 1/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.3160 - loss: 2.3846 - val_accuracy: 0.7283 - val_loss: 1.4820 - learning_rate: 0.0100
# Epoch 2/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7071 - loss: 1.6911 - val_accuracy: 0.9265 - val_loss: 1.4794 - learning_rate: 0.0100
# Epoch 3/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8169 - loss: 1.7425 - val_accuracy: 0.9510 - val_loss: 1.5059 - learning_rate: 0.0100
# Epoch 4/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8470 - loss: 1.8903 - val_accuracy: 0.8753 - val_loss: 2.0380 - learning_rate: 0.0100
# Epoch 5/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8400 - loss: 2.1240 - val_accuracy: 0.9465 - val_loss: 1.4878 - learning_rate: 0.0100
# Epoch 6/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8588 - loss: 1.9722 - val_accuracy: 0.9488 - val_loss: 1.7510 - learning_rate: 0.0100
# Epoch 7/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8508 - loss: 1.9726 - val_accuracy: 0.9310 - val_loss: 1.5384 - learning_rate: 0.0100
# Epoch 8/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8677 - loss: 1.7140 - val_accuracy: 0.9822 - val_loss: 1.0137 - learning_rate: 0.0050
# Epoch 9/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9084 - loss: 1.2751 - val_accuracy: 0.9666 - val_loss: 1.0898 - learning_rate: 0.0050
# Epoch 10/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8882 - loss: 1.4692 - val_accuracy: 0.9599 - val_loss: 1.1142 - learning_rate: 0.0050
# Epoch 11/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8901 - loss: 1.4263 - val_accuracy: 0.9666 - val_loss: 1.0832 - learning_rate: 0.0050
# Epoch 12/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9100 - loss: 1.3507 - val_accuracy: 0.9889 - val_loss: 0.9452 - learning_rate: 0.0050
# Epoch 13/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9234 - loss: 1.1991 - val_accuracy: 0.9755 - val_loss: 1.0603 - learning_rate: 0.0050
# Epoch 14/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8995 - loss: 1.4188 - val_accuracy: 0.9755 - val_loss: 1.1527 - learning_rate: 0.0050
# Epoch 15/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9004 - loss: 1.4134 - val_accuracy: 0.9777 - val_loss: 1.0937 - learning_rate: 0.0050
# Epoch 16/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9156 - loss: 1.3770 - val_accuracy: 0.9555 - val_loss: 1.2503 - learning_rate: 0.0050
# Epoch 17/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.8776 - loss: 1.5598 - val_accuracy: 0.9777 - val_loss: 1.1601 - learning_rate: 0.0050
# Epoch 18/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9235 - loss: 1.3211 - val_accuracy: 0.9777 - val_loss: 1.0266 - learning_rate: 0.0025
# Epoch 19/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9314 - loss: 1.1928 - val_accuracy: 0.9532 - val_loss: 0.9831 - learning_rate: 0.0025
# Epoch 20/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9372 - loss: 1.0467 - val_accuracy: 0.9911 - val_loss: 0.7959 - learning_rate: 0.0025
# Epoch 21/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9422 - loss: 1.0037 - val_accuracy: 0.9933 - val_loss: 0.7422 - learning_rate: 0.0025
# Epoch 22/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9408 - loss: 0.9480 - val_accuracy: 0.9866 - val_loss: 0.7243 - learning_rate: 0.0025
# Epoch 23/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9435 - loss: 0.8903 - val_accuracy: 0.9978 - val_loss: 0.6868 - learning_rate: 0.0025
# Epoch 24/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9337 - loss: 0.9341 - val_accuracy: 0.9889 - val_loss: 0.6870 - learning_rate: 0.0025
# Epoch 25/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9305 - loss: 0.9469 - val_accuracy: 0.9733 - val_loss: 0.7098 - learning_rate: 0.0025
# Epoch 26/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9418 - loss: 0.8788 - val_accuracy: 0.9844 - val_loss: 0.6973 - learning_rate: 0.0025
# Epoch 27/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9404 - loss: 0.8537 - val_accuracy: 0.9933 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 28/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9369 - loss: 0.8663 - val_accuracy: 0.9933 - val_loss: 0.6491 - learning_rate: 0.0025
# Epoch 29/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9455 - loss: 0.8641 - val_accuracy: 0.9755 - val_loss: 0.7223 - learning_rate: 0.0025
# Epoch 30/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9561 - loss: 0.7976 - val_accuracy: 0.9844 - val_loss: 0.7078 - learning_rate: 0.0025
# Epoch 31/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9406 - loss: 0.8938 - val_accuracy: 0.9933 - val_loss: 0.6604 - learning_rate: 0.0025
# Epoch 32/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9343 - loss: 0.8984 - val_accuracy: 0.9889 - val_loss: 0.7040 - learning_rate: 0.0025
# Epoch 33/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9464 - loss: 0.8468 - val_accuracy: 0.9866 - val_loss: 0.6804 - learning_rate: 0.0025
# Epoch 34/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9424 - loss: 0.8429 - val_accuracy: 0.9911 - val_loss: 0.6540 - learning_rate: 0.0012
# Epoch 35/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9500 - loss: 0.7794 - val_accuracy: 0.9866 - val_loss: 0.6002 - learning_rate: 0.0012
# Epoch 36/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9592 - loss: 0.7260 - val_accuracy: 0.9933 - val_loss: 0.5536 - learning_rate: 0.0012
# Epoch 37/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9478 - loss: 0.7406 - val_accuracy: 0.9911 - val_loss: 0.5328 - learning_rate: 0.0012
# Epoch 38/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9530 - loss: 0.7023 - val_accuracy: 0.9978 - val_loss: 0.4981 - learning_rate: 0.0012
# Epoch 39/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9475 - loss: 0.6804 - val_accuracy: 0.9933 - val_loss: 0.5042 - learning_rate: 0.0012
# Epoch 40/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9575 - loss: 0.6615 - val_accuracy: 0.9844 - val_loss: 0.5160 - learning_rate: 0.0012
# Epoch 41/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9633 - loss: 0.5963 - val_accuracy: 0.9978 - val_loss: 0.4399 - learning_rate: 0.0012
# Epoch 42/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9579 - loss: 0.6267 - val_accuracy: 0.9911 - val_loss: 0.4537 - learning_rate: 0.0012
# Epoch 43/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9588 - loss: 0.5947 - val_accuracy: 0.9978 - val_loss: 0.4244 - learning_rate: 0.0012
# Epoch 44/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9811 - loss: 0.5234 - val_accuracy: 0.9978 - val_loss: 0.4162 - learning_rate: 0.0012
# Epoch 45/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9677 - loss: 0.5486 - val_accuracy: 0.9955 - val_loss: 0.4098 - learning_rate: 0.0012
# Epoch 46/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9653 - loss: 0.5450 - val_accuracy: 0.9978 - val_loss: 0.4074 - learning_rate: 0.0012
# Epoch 47/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9538 - loss: 0.5771 - val_accuracy: 0.9889 - val_loss: 0.4424 - learning_rate: 0.0012
# Epoch 48/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9590 - loss: 0.5722 - val_accuracy: 0.9955 - val_loss: 0.4174 - learning_rate: 0.0012
# Epoch 49/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9494 - loss: 0.6653 - val_accuracy: 0.9933 - val_loss: 0.4269 - learning_rate: 0.0012
# Epoch 50/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9521 - loss: 0.5999 - val_accuracy: 0.9933 - val_loss: 0.3973 - learning_rate: 0.0012
# Epoch 51/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9635 - loss: 0.5472 - val_accuracy: 0.9911 - val_loss: 0.4380 - learning_rate: 0.0012
# Epoch 52/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9674 - loss: 0.5183 - val_accuracy: 0.9911 - val_loss: 0.4098 - learning_rate: 0.0012
# Epoch 53/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9681 - loss: 0.5044 - val_accuracy: 0.9933 - val_loss: 0.4033 - learning_rate: 0.0012
# Epoch 54/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9652 - loss: 0.5064 - val_accuracy: 0.9889 - val_loss: 0.4170 - learning_rate: 0.0012
# Epoch 55/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9626 - loss: 0.5328 - val_accuracy: 0.9933 - val_loss: 0.3967 - learning_rate: 0.0012
# Epoch 56/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9594 - loss: 0.5299 - val_accuracy: 0.9933 - val_loss: 0.3993 - learning_rate: 0.0012
# Epoch 57/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9520 - loss: 0.5763 - val_accuracy: 0.9822 - val_loss: 0.4218 - learning_rate: 0.0012
# Epoch 58/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9602 - loss: 0.5136 - val_accuracy: 0.9933 - val_loss: 0.3816 - learning_rate: 0.0012
# Epoch 59/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9498 - loss: 0.5484 - val_accuracy: 0.9933 - val_loss: 0.3758 - learning_rate: 0.0012
# Epoch 60/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9598 - loss: 0.5207 - val_accuracy: 0.9978 - val_loss: 0.3657 - learning_rate: 0.0012
# Epoch 61/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9623 - loss: 0.4918 - val_accuracy: 0.9978 - val_loss: 0.3568 - learning_rate: 0.0012
# Epoch 62/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9648 - loss: 0.4877 - val_accuracy: 0.9955 - val_loss: 0.3621 - learning_rate: 0.0012
# Epoch 63/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9714 - loss: 0.4794 - val_accuracy: 0.9889 - val_loss: 0.4224 - learning_rate: 0.0012
# Epoch 64/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9704 - loss: 0.4631 - val_accuracy: 0.9933 - val_loss: 0.3649 - learning_rate: 0.0012
# Epoch 65/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9656 - loss: 0.4905 - val_accuracy: 0.9933 - val_loss: 0.3646 - learning_rate: 0.0012
# Epoch 66/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9655 - loss: 0.5019 - val_accuracy: 0.9955 - val_loss: 0.3578 - learning_rate: 0.0012
# Epoch 67/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9720 - loss: 0.4634 - val_accuracy: 1.0000 - val_loss: 0.3240 - learning_rate: 6.2500e-04
# Epoch 68/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9625 - loss: 0.4729 - val_accuracy: 0.9955 - val_loss: 0.3306 - learning_rate: 6.2500e-04
# Epoch 69/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9640 - loss: 0.4721 - val_accuracy: 0.9955 - val_loss: 0.3303 - learning_rate: 6.2500e-04
# Epoch 70/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9726 - loss: 0.4192 - val_accuracy: 0.9978 - val_loss: 0.3019 - learning_rate: 6.2500e-04
# Epoch 71/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9766 - loss: 0.4134 - val_accuracy: 0.9978 - val_loss: 0.3076 - learning_rate: 6.2500e-04
# Epoch 72/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9667 - loss: 0.4218 - val_accuracy: 0.9978 - val_loss: 0.2976 - learning_rate: 6.2500e-04
# Epoch 73/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9710 - loss: 0.4003 - val_accuracy: 0.9955 - val_loss: 0.3305 - learning_rate: 6.2500e-04
# Epoch 74/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9587 - loss: 0.4418 - val_accuracy: 1.0000 - val_loss: 0.2730 - learning_rate: 6.2500e-04
# Epoch 75/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9698 - loss: 0.3928 - val_accuracy: 0.9978 - val_loss: 0.2866 - learning_rate: 6.2500e-04
# Epoch 76/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9744 - loss: 0.3786 - val_accuracy: 0.9978 - val_loss: 0.2785 - learning_rate: 6.2500e-04
# Epoch 77/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9780 - loss: 0.3554 - val_accuracy: 0.9978 - val_loss: 0.2663 - learning_rate: 6.2500e-04
# Epoch 78/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9725 - loss: 0.3926 - val_accuracy: 0.9933 - val_loss: 0.3136 - learning_rate: 6.2500e-04
# Epoch 79/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9696 - loss: 0.3740 - val_accuracy: 0.9978 - val_loss: 0.2786 - learning_rate: 6.2500e-04
# Epoch 80/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9648 - loss: 0.3818 - val_accuracy: 0.9955 - val_loss: 0.2710 - learning_rate: 6.2500e-04
# Epoch 81/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9687 - loss: 0.3697 - val_accuracy: 0.9933 - val_loss: 0.2762 - learning_rate: 6.2500e-04
# Epoch 82/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9784 - loss: 0.3416 - val_accuracy: 0.9889 - val_loss: 0.3064 - learning_rate: 6.2500e-04
# Epoch 83/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9703 - loss: 0.3435 - val_accuracy: 0.9978 - val_loss: 0.2655 - learning_rate: 3.1250e-04
# Epoch 84/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9661 - loss: 0.3714 - val_accuracy: 0.9889 - val_loss: 0.2916 - learning_rate: 3.1250e-04
# Epoch 85/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9725 - loss: 0.3377 - val_accuracy: 0.9978 - val_loss: 0.2550 - learning_rate: 3.1250e-04
# Epoch 86/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9711 - loss: 0.3350 - val_accuracy: 0.9978 - val_loss: 0.2422 - learning_rate: 3.1250e-04
# Epoch 87/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9694 - loss: 0.3703 - val_accuracy: 0.9933 - val_loss: 0.2482 - learning_rate: 3.1250e-04
# Epoch 88/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9764 - loss: 0.3220 - val_accuracy: 0.9889 - val_loss: 0.3066 - learning_rate: 3.1250e-04
# Epoch 89/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9780 - loss: 0.3191 - val_accuracy: 0.9978 - val_loss: 0.2337 - learning_rate: 3.1250e-04
# Epoch 90/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9723 - loss: 0.3180 - val_accuracy: 0.9955 - val_loss: 0.2422 - learning_rate: 3.1250e-04
# Epoch 91/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9787 - loss: 0.2945 - val_accuracy: 0.9822 - val_loss: 0.3531 - learning_rate: 3.1250e-04
# Epoch 92/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9805 - loss: 0.2946 - val_accuracy: 0.9978 - val_loss: 0.2217 - learning_rate: 3.1250e-04
# Epoch 93/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9756 - loss: 0.2975 - val_accuracy: 0.9978 - val_loss: 0.2257 - learning_rate: 3.1250e-04
# Epoch 94/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9767 - loss: 0.3215 - val_accuracy: 0.9978 - val_loss: 0.2216 - learning_rate: 3.1250e-04
# Epoch 95/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9831 - loss: 0.2707 - val_accuracy: 0.9978 - val_loss: 0.2182 - learning_rate: 3.1250e-04
# Epoch 96/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9784 - loss: 0.2771 - val_accuracy: 0.9933 - val_loss: 0.2514 - learning_rate: 3.1250e-04
# Epoch 97/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9806 - loss: 0.2765 - val_accuracy: 0.9978 - val_loss: 0.2007 - learning_rate: 3.1250e-04
# Epoch 98/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9811 - loss: 0.2869 - val_accuracy: 0.9955 - val_loss: 0.2010 - learning_rate: 3.1250e-04
# Epoch 99/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9810 - loss: 0.2588 - val_accuracy: 1.0000 - val_loss: 0.1871 - learning_rate: 3.1250e-04
# Epoch 100/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9831 - loss: 0.2784 - val_accuracy: 0.9978 - val_loss: 0.1979 - learning_rate: 3.1250e-04
#  Epoch  Training Accuracy  Training Loss  Validation Accuracy  Validation Loss
#      0           0.437460       2.265521             0.728285         1.482013
#     10           0.903810       1.349204             0.966592         1.083225
#     20           0.942857       0.991683             0.993318         0.742152
#     30           0.941587       0.886760             0.993318         0.660354
#     40           0.956825       0.618874             0.997773         0.439869
#     50           0.964762       0.536884             0.991091         0.438040
#     60           0.955556       0.522775             0.997773         0.356772
#     70           0.973651       0.408737             0.997773         0.307565
#     80           0.969524       0.371061             0.993318         0.276173
#     90           0.974921       0.308738             0.982183         0.353139
#     99           0.977143       0.295021             0.997773         0.197866

# %%
import matplotlib.pyplot as plt

model.save("mlp_model_ResNet50.h5")

print("Model saved successfully!!")

plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy for ResNet50')
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!!

# %%
import os
import pickle
import numpy as np


directory = "C:\\COLON_CANCER DATASET\\PolypDB\\PolypDB_modality_wise\\AUG_PICS\\Model_Test_Feature_PKLs\\ResNet50"


modalities = ["bli", "wli", "nbi", "fice", "lci"]


for modality in modalities:
    con_features = []
    count = 0

    for file in os.listdir(directory):
        if modality in file.lower():  
            filename = os.path.join(directory, file)
            count += 1
            with open(filename, 'rb') as f:
                data = pickle.load(f)
                l = len(data)
                con_features.append(data)

    if count > 0:
       
        con_features_arr = np.concatenate(con_features, axis=0)
        con_features_mod = con_features_arr.reshape(count, l)

        
        np.save(f"CONCATENATED_FEATURES_TEST_{modality.upper()}_Res50.npy", con_features_mod)

        print(f"Saved {modality.upper()} test features successfully! Shape: {con_features_mod.shape}")
    else:
        print(f"No files found for {modality.upper()}.")
# Out:
# Saved BLI test features successfully! Shape: (196, 2048)
# Saved WLI test features successfully! Shape: (162, 2048)
# Saved NBI test features successfully! Shape: (180, 2048)
# Saved FICE test features successfully! Shape: (189, 2048)
# Saved LCI test features successfully! Shape: (174, 2048)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, log_loss


model = load_model("mlp_model_ResNet50.h5")


modalities = ["BLI", "WLI", "FICE", "LCI", "NBI"]
label_order = ["BLI", "FICE", "LCI", "NBI", "WLI"]
label_map = {modality: idx for idx, modality in enumerate(label_order)}


def plot_confusion_matrix(y_true, y_pred, modality):
    cm = confusion_matrix(y_true, y_pred, labels=range(5))
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=label_order, yticklabels=label_order)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix - {modality}")
    plt.show()


l_dense = []


for modality in modalities:
    X_test = np.load(f"CONCATENATED_FEATURES_TEST_{modality}_Res50.npy")
    
   
    modality_label = label_map[modality]
    y_test = np.full(shape=(len(X_test),), fill_value=modality_label)

    num_classes = 5  
    y_test_one_hot = tf.keras.utils.to_categorical(y_test, num_classes=num_classes)

    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test_one_hot, axis=1)

   
    accuracy = accuracy_score(y_true, y_pred)
    logloss = log_loss(y_test_one_hot, y_pred_probs)
    l_dense.append(logloss)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

   
    print(f"Results for {modality}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")
    print(f"Log Loss: {logloss:.4f}")
    print(f"Unique labels in y_test: {np.unique(y_test)}")
    print("-" * 40)

    
    plot_confusion_matrix(y_true, y_pred, modality)


print(f"Average Log_loss for the Resnet50: {sum(l_dense)/5:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Results for BLI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0006
# Unique labels in y_test: [0]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for WLI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0002
# Unique labels in y_test: [4]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for FICE:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0000
# Unique labels in y_test: [1]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for LCI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0007
# Unique labels in y_test: [2]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Results for NBI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0003
# Unique labels in y_test: [3]
# ----------------------------------------
# Average Log_loss for the Resnet50: 0.0004
