# %%
import os
os.chdir("C:\\COLON_CANCER DATASET")

# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks, regularizers
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


X_train = np.load("CONCATENATED_FEATURES_TRAIN_Res101.npy")  
y_train = np.load("Training_labels.npy")    
X_val = np.load("CONCATENATED_FEATURES_VALIDATE_Res101.npy")
y_val = np.load("Validation_labels.npy")

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")


num_classes = 5  
y_train = to_categorical(y_train, num_classes=num_classes)
y_val = to_categorical(y_val, num_classes=num_classes)


def build_mlp(input_shape=(2048,), num_classes=5):
    inputs = layers.Input(shape=input_shape)
    x = layers.Dense(1024, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(inputs)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(512, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(256, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.55)(x)
    
    x = layers.Dense(128, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(64, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(32, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.45)(x)

    x = layers.Dense(16, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.35)(x)
    
    outputs = layers.Dense(num_classes, activation='softmax')(x)  
    
    model = models.Model(inputs, outputs)
    optimizer = optimizers.AdamW(learning_rate=0.01, weight_decay=1e-4, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

if __name__ == "__main__":
    model = build_mlp()
    model.summary()
    
    lr_scheduler = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[lr_scheduler])
    
    
    log_data = []
    for epoch in range(0, len(history.history['accuracy']), 10):
        log_data.append([
            epoch,
            history.history['accuracy'][epoch],
            history.history['loss'][epoch],
            history.history['val_accuracy'][epoch],
            history.history['val_loss'][epoch]
        ])

    if (len(history.history['accuracy']) - 1) % 10 != 0:
        last_epoch = len(history.history['accuracy']) - 1
        log_data.append([
            last_epoch,
            history.history['accuracy'][last_epoch],
            history.history['loss'][last_epoch],
            history.history['val_accuracy'][last_epoch],
            history.history['val_loss'][last_epoch]
        ])
    
   
    log_df = pd.DataFrame(log_data, columns=['Epoch', 'Training Accuracy', 'Training Loss', 'Validation Accuracy', 'Validation Loss'])
    print(log_df.to_string(index=False))
# Out:
# X_train shape: (3150, 2048), y_train shape: (3150,)
# X_val shape: (449, 2048), y_val shape: (449,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_2 (ReLU)                       │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_3 (ReLU)                       │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_4 (ReLU)                       │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_5 (ReLU)                       │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_6 (ReLU)                       │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 5)                   │              85 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,806,277 (10.71 MB)
#  Trainable params: 2,802,213 (10.69 MB)
#  Non-trainable params: 4,064 (15.88 KB)
# Epoch 1/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.2985 - loss: 2.4215 - val_accuracy: 0.8463 - val_loss: 1.4615 - learning_rate: 0.0100
# Epoch 2/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7251 - loss: 1.6263 - val_accuracy: 0.9399 - val_loss: 1.3197 - learning_rate: 0.0100
# Epoch 3/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8296 - loss: 1.7194 - val_accuracy: 0.9621 - val_loss: 1.4992 - learning_rate: 0.0100
# Epoch 4/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8493 - loss: 1.9186 - val_accuracy: 0.9555 - val_loss: 1.7443 - learning_rate: 0.0100
# Epoch 5/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8828 - loss: 1.9069 - val_accuracy: 0.9243 - val_loss: 1.6452 - learning_rate: 0.0100
# Epoch 6/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8845 - loss: 1.8303 - val_accuracy: 0.9488 - val_loss: 1.7180 - learning_rate: 0.0100
# Epoch 7/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8611 - loss: 2.0960 - val_accuracy: 0.9755 - val_loss: 1.6413 - learning_rate: 0.0100
# Epoch 8/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9018 - loss: 1.7668 - val_accuracy: 0.9755 - val_loss: 1.3428 - learning_rate: 0.0050
# Epoch 9/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9082 - loss: 1.5576 - val_accuracy: 0.9733 - val_loss: 1.1671 - learning_rate: 0.0050
# Epoch 10/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9030 - loss: 1.4220 - val_accuracy: 0.9777 - val_loss: 1.1331 - learning_rate: 0.0050
# Epoch 11/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8946 - loss: 1.4064 - val_accuracy: 0.9621 - val_loss: 1.2170 - learning_rate: 0.0050
# Epoch 12/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9141 - loss: 1.3746 - val_accuracy: 0.9822 - val_loss: 1.0466 - learning_rate: 0.0050
# Epoch 13/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9107 - loss: 1.3321 - val_accuracy: 0.9710 - val_loss: 1.0368 - learning_rate: 0.0050
# Epoch 14/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9100 - loss: 1.3304 - val_accuracy: 0.9800 - val_loss: 1.0608 - learning_rate: 0.0050
# Epoch 15/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9139 - loss: 1.3250 - val_accuracy: 0.9555 - val_loss: 1.1280 - learning_rate: 0.0050
# Epoch 16/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9178 - loss: 1.2404 - val_accuracy: 0.9800 - val_loss: 1.0226 - learning_rate: 0.0050
# Epoch 17/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9001 - loss: 1.4115 - val_accuracy: 0.9933 - val_loss: 1.0396 - learning_rate: 0.0050
# Epoch 18/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9288 - loss: 1.2955 - val_accuracy: 0.9755 - val_loss: 1.0436 - learning_rate: 0.0050
# Epoch 19/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9095 - loss: 1.2895 - val_accuracy: 0.9621 - val_loss: 1.1225 - learning_rate: 0.0050
# Epoch 20/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9215 - loss: 1.2566 - val_accuracy: 0.9844 - val_loss: 0.9876 - learning_rate: 0.0050
# Epoch 21/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9315 - loss: 1.2160 - val_accuracy: 0.9733 - val_loss: 1.0625 - learning_rate: 0.0050
# Epoch 22/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9006 - loss: 1.3215 - val_accuracy: 0.9889 - val_loss: 1.0819 - learning_rate: 0.0050
# Epoch 23/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9237 - loss: 1.3032 - val_accuracy: 0.9755 - val_loss: 1.0474 - learning_rate: 0.0050
# Epoch 24/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9213 - loss: 1.2555 - val_accuracy: 0.9800 - val_loss: 1.0176 - learning_rate: 0.0050
# Epoch 25/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9134 - loss: 1.3197 - val_accuracy: 0.9755 - val_loss: 1.1169 - learning_rate: 0.0050
# Epoch 26/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9186 - loss: 1.2848 - val_accuracy: 0.9800 - val_loss: 0.9985 - learning_rate: 0.0025
# Epoch 27/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9335 - loss: 1.1444 - val_accuracy: 0.9733 - val_loss: 0.8809 - learning_rate: 0.0025
# Epoch 28/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9241 - loss: 1.0946 - val_accuracy: 0.9911 - val_loss: 0.7643 - learning_rate: 0.0025
# Epoch 29/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9559 - loss: 0.9490 - val_accuracy: 0.9866 - val_loss: 0.7551 - learning_rate: 0.0025
# Epoch 30/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9364 - loss: 0.9538 - val_accuracy: 0.9889 - val_loss: 0.7231 - learning_rate: 0.0025
# Epoch 31/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9490 - loss: 0.8752 - val_accuracy: 0.9755 - val_loss: 0.7388 - learning_rate: 0.0025
# Epoch 32/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9440 - loss: 0.8395 - val_accuracy: 0.9933 - val_loss: 0.7051 - learning_rate: 0.0025
# Epoch 33/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9420 - loss: 0.9116 - val_accuracy: 0.9666 - val_loss: 0.8178 - learning_rate: 0.0025
# Epoch 34/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9383 - loss: 0.8843 - val_accuracy: 0.9844 - val_loss: 0.6987 - learning_rate: 0.0025
# Epoch 35/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9483 - loss: 0.8258 - val_accuracy: 0.9777 - val_loss: 0.6599 - learning_rate: 0.0025
# Epoch 36/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9397 - loss: 0.8190 - val_accuracy: 0.9955 - val_loss: 0.6295 - learning_rate: 0.0025
# Epoch 37/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9458 - loss: 0.8404 - val_accuracy: 0.9911 - val_loss: 0.6650 - learning_rate: 0.0025
# Epoch 38/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9354 - loss: 0.8809 - val_accuracy: 0.9978 - val_loss: 0.6333 - learning_rate: 0.0025
# Epoch 39/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9479 - loss: 0.8090 - val_accuracy: 0.9755 - val_loss: 0.6713 - learning_rate: 0.0025
# Epoch 40/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9398 - loss: 0.8121 - val_accuracy: 0.9844 - val_loss: 0.6992 - learning_rate: 0.0025
# Epoch 41/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9333 - loss: 0.8665 - val_accuracy: 0.9688 - val_loss: 0.7923 - learning_rate: 0.0025
# Epoch 42/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9505 - loss: 0.8117 - val_accuracy: 0.9911 - val_loss: 0.5989 - learning_rate: 0.0012
# Epoch 43/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9483 - loss: 0.7576 - val_accuracy: 0.9933 - val_loss: 0.5718 - learning_rate: 0.0012
# Epoch 44/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9491 - loss: 0.7638 - val_accuracy: 0.9978 - val_loss: 0.5269 - learning_rate: 0.0012
# Epoch 45/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9510 - loss: 0.6923 - val_accuracy: 0.9978 - val_loss: 0.5075 - learning_rate: 0.0012
# Epoch 46/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9620 - loss: 0.6617 - val_accuracy: 0.9889 - val_loss: 0.5424 - learning_rate: 0.0012
# Epoch 47/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9550 - loss: 0.6820 - val_accuracy: 0.9666 - val_loss: 0.7211 - learning_rate: 0.0012
# Epoch 48/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9540 - loss: 0.6601 - val_accuracy: 0.9866 - val_loss: 0.5179 - learning_rate: 0.0012
# Epoch 49/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9563 - loss: 0.6348 - val_accuracy: 0.9844 - val_loss: 0.4977 - learning_rate: 0.0012
# Epoch 50/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.9586 - loss: 0.5940 - val_accuracy: 0.9777 - val_loss: 0.5636 - learning_rate: 0.0012
# Epoch 51/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9633 - loss: 0.5647 - val_accuracy: 1.0000 - val_loss: 0.4158 - learning_rate: 0.0012
# Epoch 52/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9595 - loss: 0.5937 - val_accuracy: 0.9955 - val_loss: 0.4426 - learning_rate: 0.0012
# Epoch 53/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.9580 - loss: 0.5666 - val_accuracy: 0.9955 - val_loss: 0.4215 - learning_rate: 0.0012
# Epoch 54/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9598 - loss: 0.5580 - val_accuracy: 0.9911 - val_loss: 0.4883 - learning_rate: 0.0012
# Epoch 55/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9502 - loss: 0.5764 - val_accuracy: 0.9866 - val_loss: 0.4398 - learning_rate: 0.0012
# Epoch 56/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9648 - loss: 0.5301 - val_accuracy: 0.9978 - val_loss: 0.3849 - learning_rate: 0.0012
# Epoch 57/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9610 - loss: 0.5626 - val_accuracy: 0.9955 - val_loss: 0.4064 - learning_rate: 0.0012
# Epoch 58/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9685 - loss: 0.5093 - val_accuracy: 0.9911 - val_loss: 0.4065 - learning_rate: 0.0012
# Epoch 59/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9571 - loss: 0.5328 - val_accuracy: 0.9911 - val_loss: 0.4020 - learning_rate: 0.0012
# Epoch 60/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9547 - loss: 0.5177 - val_accuracy: 0.9866 - val_loss: 0.4362 - learning_rate: 0.0012
# Epoch 61/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9642 - loss: 0.5080 - val_accuracy: 0.9955 - val_loss: 0.3768 - learning_rate: 0.0012
# Epoch 62/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9617 - loss: 0.5162 - val_accuracy: 0.9822 - val_loss: 0.4735 - learning_rate: 0.0012
# Epoch 63/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9592 - loss: 0.5262 - val_accuracy: 0.9822 - val_loss: 0.4880 - learning_rate: 0.0012
# Epoch 64/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9608 - loss: 0.5512 - val_accuracy: 0.9978 - val_loss: 0.3550 - learning_rate: 0.0012
# Epoch 65/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9524 - loss: 0.5225 - val_accuracy: 0.9955 - val_loss: 0.3842 - learning_rate: 0.0012
# Epoch 66/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9587 - loss: 0.5169 - val_accuracy: 0.9822 - val_loss: 0.5126 - learning_rate: 0.0012
# Epoch 67/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9574 - loss: 0.5034 - val_accuracy: 0.9933 - val_loss: 0.3956 - learning_rate: 0.0012
# Epoch 68/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9668 - loss: 0.4955 - val_accuracy: 0.9866 - val_loss: 0.4419 - learning_rate: 0.0012
# Epoch 69/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9618 - loss: 0.4790 - val_accuracy: 0.9933 - val_loss: 0.3657 - learning_rate: 0.0012
# Epoch 70/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9642 - loss: 0.4914 - val_accuracy: 0.9955 - val_loss: 0.3566 - learning_rate: 6.2500e-04
# Epoch 71/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9648 - loss: 0.4591 - val_accuracy: 0.9889 - val_loss: 0.3754 - learning_rate: 6.2500e-04
# Epoch 72/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9714 - loss: 0.4444 - val_accuracy: 0.9889 - val_loss: 0.3587 - learning_rate: 6.2500e-04
# Epoch 73/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9633 - loss: 0.4381 - val_accuracy: 0.9978 - val_loss: 0.3136 - learning_rate: 6.2500e-04
# Epoch 74/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9721 - loss: 0.4134 - val_accuracy: 0.9933 - val_loss: 0.3338 - learning_rate: 6.2500e-04
# Epoch 75/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9666 - loss: 0.4130 - val_accuracy: 0.9933 - val_loss: 0.3200 - learning_rate: 6.2500e-04
# Epoch 76/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9643 - loss: 0.4362 - val_accuracy: 0.9955 - val_loss: 0.3159 - learning_rate: 6.2500e-04
# Epoch 77/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9733 - loss: 0.3837 - val_accuracy: 0.9978 - val_loss: 0.3049 - learning_rate: 6.2500e-04
# Epoch 78/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9631 - loss: 0.4149 - val_accuracy: 0.9978 - val_loss: 0.2983 - learning_rate: 6.2500e-04
# Epoch 79/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.9789 - loss: 0.3703 - val_accuracy: 0.9955 - val_loss: 0.2971 - learning_rate: 6.2500e-04
# Epoch 80/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9778 - loss: 0.3565 - val_accuracy: 0.9955 - val_loss: 0.2961 - learning_rate: 6.2500e-04
# Epoch 81/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.9698 - loss: 0.3456 - val_accuracy: 1.0000 - val_loss: 0.2541 - learning_rate: 6.2500e-04
# Epoch 82/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9675 - loss: 0.3854 - val_accuracy: 0.9978 - val_loss: 0.2570 - learning_rate: 6.2500e-04
# Epoch 83/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9743 - loss: 0.3448 - val_accuracy: 1.0000 - val_loss: 0.2485 - learning_rate: 6.2500e-04
# Epoch 84/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9659 - loss: 0.3596 - val_accuracy: 0.9978 - val_loss: 0.2465 - learning_rate: 6.2500e-04
# Epoch 85/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9649 - loss: 0.3526 - val_accuracy: 0.9978 - val_loss: 0.2747 - learning_rate: 6.2500e-04
# Epoch 86/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9680 - loss: 0.3681 - val_accuracy: 0.9955 - val_loss: 0.2644 - learning_rate: 6.2500e-04
# Epoch 87/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9681 - loss: 0.3378 - val_accuracy: 1.0000 - val_loss: 0.2353 - learning_rate: 6.2500e-04
# Epoch 88/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9706 - loss: 0.3354 - val_accuracy: 0.9933 - val_loss: 0.2543 - learning_rate: 6.2500e-04
# Epoch 89/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9723 - loss: 0.3245 - val_accuracy: 0.9933 - val_loss: 0.2771 - learning_rate: 6.2500e-04
# Epoch 90/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9756 - loss: 0.3324 - val_accuracy: 0.9978 - val_loss: 0.2274 - learning_rate: 6.2500e-04
# Epoch 91/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9673 - loss: 0.3659 - val_accuracy: 0.9911 - val_loss: 0.2933 - learning_rate: 6.2500e-04
# Epoch 92/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9702 - loss: 0.3172 - val_accuracy: 0.9933 - val_loss: 0.2713 - learning_rate: 6.2500e-04
# Epoch 93/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9715 - loss: 0.3360 - val_accuracy: 0.9933 - val_loss: 0.2484 - learning_rate: 6.2500e-04
# Epoch 94/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9706 - loss: 0.3138 - val_accuracy: 0.9955 - val_loss: 0.2395 - learning_rate: 6.2500e-04
# Epoch 95/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9710 - loss: 0.3182 - val_accuracy: 0.9889 - val_loss: 0.3327 - learning_rate: 6.2500e-04
# Epoch 96/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9709 - loss: 0.3179 - val_accuracy: 0.9978 - val_loss: 0.2336 - learning_rate: 3.1250e-04
# Epoch 97/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9670 - loss: 0.3034 - val_accuracy: 1.0000 - val_loss: 0.2074 - learning_rate: 3.1250e-04
# Epoch 98/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9739 - loss: 0.3095 - val_accuracy: 0.9911 - val_loss: 0.2710 - learning_rate: 3.1250e-04
# Epoch 99/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9729 - loss: 0.3189 - val_accuracy: 0.9933 - val_loss: 0.2442 - learning_rate: 3.1250e-04
# Epoch 100/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9724 - loss: 0.2967 - val_accuracy: 0.9955 - val_loss: 0.2473 - learning_rate: 3.1250e-04
#  Epoch  Training Accuracy  Training Loss  Validation Accuracy  Validation Loss
#      0           0.423175       2.314747             0.846325         1.461517
#     10           0.899683       1.424735             0.962138         1.217037
#     20           0.913968       1.274911             0.973274         1.062452
#     30           0.941587       0.901723             0.975501         0.738752
#     40           0.933016       0.876713             0.968820         0.792299
#     50           0.959048       0.579741             1.000000         0.415813
#     60           0.957143       0.526953             0.995546         0.376828
#     70           0.959683       0.480855             0.988864         0.375438
#     80           0.973968       0.341414             1.000000         0.254146
#     90           0.965397       0.370895             0.991091         0.293325
#     99           0.972698       0.300185             0.995546         0.247300

# %%
import matplotlib.pyplot as plt

model.save("mlp_model_ResNet101.h5")

print("Model saved successfully!!")

plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy for ResNet101')
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!!

# %%
import os
import pickle
import numpy as np


directory = "C:\\COLON_CANCER DATASET\\PolypDB\\PolypDB_modality_wise\\AUG_PICS\\Model_Test_Feature_PKLs\\ResNet101"


modalities = ["bli", "wli", "nbi", "fice", "lci"]


for modality in modalities:
    con_features = []
    count = 0

    for file in os.listdir(directory):
        if modality in file.lower():  
            filename = os.path.join(directory, file)
            count += 1
            with open(filename, 'rb') as f:
                data = pickle.load(f)
                l = len(data)
                con_features.append(data)

    if count > 0:
       
        con_features_arr = np.concatenate(con_features, axis=0)
        con_features_mod = con_features_arr.reshape(count, l)

        
        np.save(f"CONCATENATED_FEATURES_TEST_{modality.upper()}_Res101.npy", con_features_mod)

        print(f"Saved {modality.upper()} test features successfully! Shape: {con_features_mod.shape}")
    else:
        print(f"No files found for {modality.upper()}.")
# Out:
# Saved BLI test features successfully! Shape: (196, 2048)
# Saved WLI test features successfully! Shape: (162, 2048)
# Saved NBI test features successfully! Shape: (180, 2048)
# Saved FICE test features successfully! Shape: (189, 2048)
# Saved LCI test features successfully! Shape: (174, 2048)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, log_loss


model = load_model("mlp_model_ResNet101.h5")


modalities = ["BLI", "WLI", "FICE", "LCI", "NBI"]
label_order = ["BLI", "FICE", "LCI", "NBI", "WLI"]
label_map = {modality: idx for idx, modality in enumerate(label_order)}


def plot_confusion_matrix(y_true, y_pred, modality):
    cm = confusion_matrix(y_true, y_pred, labels=range(5))
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=label_order, yticklabels=label_order)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix - {modality}")
    plt.show()


l_dense = []


for modality in modalities:
    X_test = np.load(f"CONCATENATED_FEATURES_TEST_{modality}_Res101.npy")
    
   
    modality_label = label_map[modality]
    y_test = np.full(shape=(len(X_test),), fill_value=modality_label)

    num_classes = 5  
    y_test_one_hot = tf.keras.utils.to_categorical(y_test, num_classes=num_classes)

    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test_one_hot, axis=1)

   
    accuracy = accuracy_score(y_true, y_pred)
    logloss = log_loss(y_test_one_hot, y_pred_probs)
    l_dense.append(logloss)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

   
    print(f"Results for {modality}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")
    print(f"Log Loss: {logloss:.4f}")
    print(f"Unique labels in y_test: {np.unique(y_test)}")
    print("-" * 40)

    
    plot_confusion_matrix(y_true, y_pred, modality)


print(f"Average Log_loss for the ResNet101: {sum(l_dense)/5:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Results for BLI:
# Accuracy: 0.9949
# Precision: 1.0000
# Recall: 0.9949
# F1-score: 0.9974
# Log Loss: 0.0133
# Unique labels in y_test: [0]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Results for WLI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0008
# Unique labels in y_test: [4]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for FICE:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0000
# Unique labels in y_test: [1]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for LCI:
# Accuracy: 0.9943
# Precision: 1.0000
# Recall: 0.9943
# F1-score: 0.9971
# Log Loss: 0.0114
# Unique labels in y_test: [2]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for NBI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0000
# Unique labels in y_test: [3]
# ----------------------------------------
# Average Log_loss for the ResNet101: 0.0051
