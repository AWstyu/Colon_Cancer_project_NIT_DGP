# %%
import os
os.chdir("C:\\COLON_CANCER DATASET")

# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks, regularizers
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


X_train = np.load("CONCATENATED_FEATURES_TRAIN_VGG19.npy")  
y_train = np.load("Training_labels.npy")    
X_val = np.load("CONCATENATED_FEATURES_VALIDATE_VGG19.npy")
y_val = np.load("Validation_labels.npy")

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")


num_classes = 5  
y_train = to_categorical(y_train, num_classes=num_classes)
y_val = to_categorical(y_val, num_classes=num_classes)


def build_mlp(input_shape=(512,), num_classes=5):
    inputs = layers.Input(shape=input_shape)
    x = layers.Dense(1024, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(inputs)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(512, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(256, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.55)(x)
    
    x = layers.Dense(128, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(64, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(32, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.45)(x)

    x = layers.Dense(16, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.35)(x)
    
    outputs = layers.Dense(num_classes, activation='softmax')(x)  
    
    model = models.Model(inputs, outputs)
    optimizer = optimizers.AdamW(learning_rate=0.01, weight_decay=1e-4, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

if __name__ == "__main__":
    model = build_mlp()
    model.summary()
    
    lr_scheduler = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[lr_scheduler])
    
    
    log_data = []
    for epoch in range(0, len(history.history['accuracy']), 10):
        log_data.append([
            epoch,
            history.history['accuracy'][epoch],
            history.history['loss'][epoch],
            history.history['val_accuracy'][epoch],
            history.history['val_loss'][epoch]
        ])

    if (len(history.history['accuracy']) - 1) % 10 != 0:
        last_epoch = len(history.history['accuracy']) - 1
        log_data.append([
            last_epoch,
            history.history['accuracy'][last_epoch],
            history.history['loss'][last_epoch],
            history.history['val_accuracy'][last_epoch],
            history.history['val_loss'][last_epoch]
        ])
    
   
    log_df = pd.DataFrame(log_data, columns=['Epoch', 'Training Accuracy', 'Training Loss', 'Validation Accuracy', 'Validation Loss'])
    print(log_df.to_string(index=False))
# Out:
# X_train shape: (3150, 512), y_train shape: (3150,)
# X_val shape: (449, 512), y_val shape: (449,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_2 (ReLU)                       │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_3 (ReLU)                       │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_4 (ReLU)                       │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_5 (ReLU)                       │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_6 (ReLU)                       │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 5)                   │              85 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,233,413 (4.71 MB)
#  Trainable params: 1,229,349 (4.69 MB)
#  Non-trainable params: 4,064 (15.88 KB)
# Epoch 1/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.2951 - loss: 2.1044 - val_accuracy: 0.7595 - val_loss: 1.5380 - learning_rate: 0.0100
# Epoch 2/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6216 - loss: 1.6271 - val_accuracy: 0.8151 - val_loss: 1.3669 - learning_rate: 0.0100
# Epoch 3/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7192 - loss: 1.5712 - val_accuracy: 0.8953 - val_loss: 1.3563 - learning_rate: 0.0100
# Epoch 4/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8015 - loss: 1.5544 - val_accuracy: 0.8820 - val_loss: 1.5205 - learning_rate: 0.0100
# Epoch 5/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8192 - loss: 1.6793 - val_accuracy: 0.9532 - val_loss: 1.3105 - learning_rate: 0.0100
# Epoch 6/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8674 - loss: 1.5667 - val_accuracy: 0.9354 - val_loss: 1.3033 - learning_rate: 0.0100
# Epoch 7/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8513 - loss: 1.5799 - val_accuracy: 0.8775 - val_loss: 1.4372 - learning_rate: 0.0100
# Epoch 8/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8445 - loss: 1.6239 - val_accuracy: 0.9465 - val_loss: 1.3260 - learning_rate: 0.0100
# Epoch 9/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8616 - loss: 1.6057 - val_accuracy: 0.9465 - val_loss: 1.2105 - learning_rate: 0.0100
# Epoch 10/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8707 - loss: 1.4446 - val_accuracy: 0.9287 - val_loss: 1.3248 - learning_rate: 0.0100
# Epoch 11/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8502 - loss: 1.6129 - val_accuracy: 0.9065 - val_loss: 1.2952 - learning_rate: 0.0100
# Epoch 12/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8626 - loss: 1.5495 - val_accuracy: 0.9332 - val_loss: 1.2720 - learning_rate: 0.0100
# Epoch 13/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8619 - loss: 1.5546 - val_accuracy: 0.9087 - val_loss: 1.3521 - learning_rate: 0.0100
# Epoch 14/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8667 - loss: 1.5230 - val_accuracy: 0.9287 - val_loss: 1.2251 - learning_rate: 0.0100
# Epoch 15/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8749 - loss: 1.4323 - val_accuracy: 0.9644 - val_loss: 1.0163 - learning_rate: 0.0050
# Epoch 16/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9034 - loss: 1.2191 - val_accuracy: 0.9399 - val_loss: 1.0665 - learning_rate: 0.0050
# Epoch 17/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8850 - loss: 1.2746 - val_accuracy: 0.9599 - val_loss: 0.9071 - learning_rate: 0.0050
# Epoch 18/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8886 - loss: 1.1726 - val_accuracy: 0.9510 - val_loss: 0.8966 - learning_rate: 0.0050
# Epoch 19/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9122 - loss: 1.0816 - val_accuracy: 0.9154 - val_loss: 1.0352 - learning_rate: 0.0050
# Epoch 20/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8928 - loss: 1.1178 - val_accuracy: 0.9265 - val_loss: 1.0891 - learning_rate: 0.0050
# Epoch 21/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8964 - loss: 1.1495 - val_accuracy: 0.9354 - val_loss: 0.9650 - learning_rate: 0.0050
# Epoch 22/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8868 - loss: 1.1722 - val_accuracy: 0.9488 - val_loss: 0.9007 - learning_rate: 0.0050
# Epoch 23/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9182 - loss: 1.0435 - val_accuracy: 0.9443 - val_loss: 0.9317 - learning_rate: 0.0050
# Epoch 24/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9058 - loss: 1.1055 - val_accuracy: 0.9666 - val_loss: 0.8191 - learning_rate: 0.0025
# Epoch 25/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9179 - loss: 1.0108 - val_accuracy: 0.9644 - val_loss: 0.7653 - learning_rate: 0.0025
# Epoch 26/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9234 - loss: 0.9357 - val_accuracy: 0.9265 - val_loss: 0.9089 - learning_rate: 0.0025
# Epoch 27/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9351 - loss: 0.8643 - val_accuracy: 0.9755 - val_loss: 0.6472 - learning_rate: 0.0025
# Epoch 28/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9350 - loss: 0.8129 - val_accuracy: 0.9666 - val_loss: 0.6686 - learning_rate: 0.0025
# Epoch 29/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9190 - loss: 0.8678 - val_accuracy: 0.9220 - val_loss: 0.8754 - learning_rate: 0.0025
# Epoch 30/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9084 - loss: 0.9082 - val_accuracy: 0.9555 - val_loss: 0.7042 - learning_rate: 0.0025
# Epoch 31/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9205 - loss: 0.8187 - val_accuracy: 0.9733 - val_loss: 0.6465 - learning_rate: 0.0025
# Epoch 32/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9232 - loss: 0.8155 - val_accuracy: 0.9644 - val_loss: 0.6335 - learning_rate: 0.0025
# Epoch 33/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9320 - loss: 0.7880 - val_accuracy: 0.9510 - val_loss: 0.7302 - learning_rate: 0.0025
# Epoch 34/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9258 - loss: 0.8005 - val_accuracy: 0.9866 - val_loss: 0.5747 - learning_rate: 0.0025
# Epoch 35/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9350 - loss: 0.7970 - val_accuracy: 0.9666 - val_loss: 0.6430 - learning_rate: 0.0025
# Epoch 36/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9309 - loss: 0.7858 - val_accuracy: 0.9866 - val_loss: 0.5495 - learning_rate: 0.0025
# Epoch 37/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9284 - loss: 0.7537 - val_accuracy: 0.9755 - val_loss: 0.5986 - learning_rate: 0.0025
# Epoch 38/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9322 - loss: 0.7746 - val_accuracy: 0.9777 - val_loss: 0.5627 - learning_rate: 0.0025
# Epoch 39/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9312 - loss: 0.7855 - val_accuracy: 0.9755 - val_loss: 0.5795 - learning_rate: 0.0025
# Epoch 40/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9351 - loss: 0.7365 - val_accuracy: 0.9755 - val_loss: 0.5695 - learning_rate: 0.0025
# Epoch 41/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9057 - loss: 0.8106 - val_accuracy: 0.9666 - val_loss: 0.6695 - learning_rate: 0.0025
# Epoch 42/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9492 - loss: 0.7139 - val_accuracy: 0.9644 - val_loss: 0.6496 - learning_rate: 0.0012
# Epoch 43/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9404 - loss: 0.7330 - val_accuracy: 0.9777 - val_loss: 0.5520 - learning_rate: 0.0012
# Epoch 44/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9391 - loss: 0.6723 - val_accuracy: 0.9822 - val_loss: 0.5127 - learning_rate: 0.0012
# Epoch 45/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9365 - loss: 0.6860 - val_accuracy: 0.9666 - val_loss: 0.5565 - learning_rate: 0.0012
# Epoch 46/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9340 - loss: 0.6679 - val_accuracy: 0.9822 - val_loss: 0.4697 - learning_rate: 0.0012
# Epoch 47/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9482 - loss: 0.6505 - val_accuracy: 0.9755 - val_loss: 0.5154 - learning_rate: 0.0012
# Epoch 48/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9434 - loss: 0.6275 - val_accuracy: 0.9666 - val_loss: 0.5170 - learning_rate: 0.0012
# Epoch 49/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9497 - loss: 0.5849 - val_accuracy: 0.9822 - val_loss: 0.4857 - learning_rate: 0.0012
# Epoch 50/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9447 - loss: 0.6047 - val_accuracy: 0.9777 - val_loss: 0.4963 - learning_rate: 0.0012
# Epoch 51/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9360 - loss: 0.6082 - val_accuracy: 0.9777 - val_loss: 0.4338 - learning_rate: 0.0012
# Epoch 52/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9569 - loss: 0.5757 - val_accuracy: 0.9822 - val_loss: 0.4289 - learning_rate: 0.0012
# Epoch 53/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9441 - loss: 0.6075 - val_accuracy: 0.9755 - val_loss: 0.4376 - learning_rate: 0.0012
# Epoch 54/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9472 - loss: 0.5459 - val_accuracy: 0.9822 - val_loss: 0.4241 - learning_rate: 0.0012
# Epoch 55/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9529 - loss: 0.5620 - val_accuracy: 0.9599 - val_loss: 0.5395 - learning_rate: 0.0012
# Epoch 56/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9547 - loss: 0.5212 - val_accuracy: 0.9733 - val_loss: 0.4821 - learning_rate: 0.0012
# Epoch 57/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9589 - loss: 0.5112 - val_accuracy: 0.9733 - val_loss: 0.4531 - learning_rate: 0.0012
# Epoch 58/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9551 - loss: 0.5392 - val_accuracy: 0.9577 - val_loss: 0.5057 - learning_rate: 0.0012
# Epoch 59/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9637 - loss: 0.5006 - val_accuracy: 0.9755 - val_loss: 0.4235 - learning_rate: 0.0012
# Epoch 60/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9625 - loss: 0.4964 - val_accuracy: 0.9866 - val_loss: 0.3915 - learning_rate: 0.0012
# Epoch 61/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9625 - loss: 0.4717 - val_accuracy: 0.9800 - val_loss: 0.4267 - learning_rate: 0.0012
# Epoch 62/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9617 - loss: 0.4815 - val_accuracy: 0.9644 - val_loss: 0.5941 - learning_rate: 0.0012
# Epoch 63/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9439 - loss: 0.5684 - val_accuracy: 0.9800 - val_loss: 0.4375 - learning_rate: 0.0012
# Epoch 64/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9542 - loss: 0.5153 - val_accuracy: 0.9755 - val_loss: 0.4188 - learning_rate: 0.0012
# Epoch 65/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9448 - loss: 0.5418 - val_accuracy: 0.9710 - val_loss: 0.4297 - learning_rate: 0.0012
# Epoch 66/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9532 - loss: 0.4858 - val_accuracy: 0.9755 - val_loss: 0.4568 - learning_rate: 6.2500e-04
# Epoch 67/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9590 - loss: 0.4675 - val_accuracy: 0.9710 - val_loss: 0.4429 - learning_rate: 6.2500e-04
# Epoch 68/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9492 - loss: 0.4886 - val_accuracy: 0.9733 - val_loss: 0.4245 - learning_rate: 6.2500e-04
# Epoch 69/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9499 - loss: 0.5291 - val_accuracy: 0.9777 - val_loss: 0.3838 - learning_rate: 6.2500e-04
# Epoch 70/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9686 - loss: 0.4344 - val_accuracy: 0.9599 - val_loss: 0.4705 - learning_rate: 6.2500e-04
# Epoch 71/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9625 - loss: 0.4259 - val_accuracy: 0.9866 - val_loss: 0.3292 - learning_rate: 6.2500e-04
# Epoch 72/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9640 - loss: 0.4187 - val_accuracy: 0.9889 - val_loss: 0.3321 - learning_rate: 6.2500e-04
# Epoch 73/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9607 - loss: 0.4332 - val_accuracy: 0.9822 - val_loss: 0.3234 - learning_rate: 6.2500e-04
# Epoch 74/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9607 - loss: 0.4579 - val_accuracy: 0.9800 - val_loss: 0.3431 - learning_rate: 6.2500e-04
# Epoch 75/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9694 - loss: 0.4116 - val_accuracy: 0.9800 - val_loss: 0.3585 - learning_rate: 6.2500e-04
# Epoch 76/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9594 - loss: 0.4259 - val_accuracy: 0.9555 - val_loss: 0.4695 - learning_rate: 6.2500e-04
# Epoch 77/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9580 - loss: 0.4327 - val_accuracy: 0.9755 - val_loss: 0.3727 - learning_rate: 6.2500e-04
# Epoch 78/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9616 - loss: 0.4625 - val_accuracy: 0.9844 - val_loss: 0.3258 - learning_rate: 6.2500e-04
# Epoch 79/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9687 - loss: 0.3849 - val_accuracy: 0.9777 - val_loss: 0.3395 - learning_rate: 3.1250e-04
# Epoch 80/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9698 - loss: 0.3778 - val_accuracy: 0.9889 - val_loss: 0.3154 - learning_rate: 3.1250e-04
# Epoch 81/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9678 - loss: 0.3751 - val_accuracy: 0.9777 - val_loss: 0.3409 - learning_rate: 3.1250e-04
# Epoch 82/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9683 - loss: 0.3788 - val_accuracy: 0.9777 - val_loss: 0.3658 - learning_rate: 3.1250e-04
# Epoch 83/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9580 - loss: 0.4076 - val_accuracy: 0.9755 - val_loss: 0.3785 - learning_rate: 3.1250e-04
# Epoch 84/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9704 - loss: 0.3765 - val_accuracy: 0.9777 - val_loss: 0.4010 - learning_rate: 3.1250e-04
# Epoch 85/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9674 - loss: 0.3917 - val_accuracy: 0.9889 - val_loss: 0.2869 - learning_rate: 3.1250e-04
# Epoch 86/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9658 - loss: 0.3637 - val_accuracy: 0.9889 - val_loss: 0.2870 - learning_rate: 3.1250e-04
# Epoch 87/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9597 - loss: 0.3987 - val_accuracy: 0.9844 - val_loss: 0.3084 - learning_rate: 3.1250e-04
# Epoch 88/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9602 - loss: 0.3628 - val_accuracy: 0.9755 - val_loss: 0.3357 - learning_rate: 3.1250e-04
# Epoch 89/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9703 - loss: 0.3489 - val_accuracy: 0.9800 - val_loss: 0.3531 - learning_rate: 3.1250e-04
# Epoch 90/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9685 - loss: 0.3684 - val_accuracy: 0.9577 - val_loss: 0.4015 - learning_rate: 3.1250e-04
# Epoch 91/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9716 - loss: 0.3336 - val_accuracy: 0.9710 - val_loss: 0.4561 - learning_rate: 1.5625e-04
# Epoch 92/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9715 - loss: 0.3327 - val_accuracy: 0.9933 - val_loss: 0.2541 - learning_rate: 1.5625e-04
# Epoch 93/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9622 - loss: 0.4036 - val_accuracy: 0.9599 - val_loss: 0.4464 - learning_rate: 1.5625e-04
# Epoch 94/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9748 - loss: 0.3370 - val_accuracy: 0.9733 - val_loss: 0.3616 - learning_rate: 1.5625e-04
# Epoch 95/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9767 - loss: 0.3196 - val_accuracy: 0.9844 - val_loss: 0.2937 - learning_rate: 1.5625e-04
# Epoch 96/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9694 - loss: 0.3520 - val_accuracy: 0.9911 - val_loss: 0.2536 - learning_rate: 1.5625e-04
# Epoch 97/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9724 - loss: 0.3274 - val_accuracy: 0.9733 - val_loss: 0.3840 - learning_rate: 1.5625e-04
# Epoch 98/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9604 - loss: 0.3653 - val_accuracy: 0.9889 - val_loss: 0.2541 - learning_rate: 1.5625e-04
# Epoch 99/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9751 - loss: 0.3204 - val_accuracy: 0.9577 - val_loss: 0.4585 - learning_rate: 1.5625e-04
# Epoch 100/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9665 - loss: 0.3313 - val_accuracy: 0.9889 - val_loss: 0.2761 - learning_rate: 1.5625e-04
#  Epoch  Training Accuracy  Training Loss  Validation Accuracy  Validation Loss
#      0           0.394921       2.031185             0.759465         1.538045
#     10           0.863492       1.566449             0.906459         1.295208
#     20           0.892381       1.156676             0.935412         0.965039
#     30           0.925714       0.826738             0.973274         0.646456
#     40           0.923810       0.777568             0.966592         0.669533
#     50           0.941587       0.583676             0.977728         0.433784
#     60           0.959683       0.480240             0.979955         0.426695
#     70           0.960000       0.440147             0.986637         0.329205
#     80           0.960317       0.405281             0.977728         0.340933
#     90           0.970159       0.350886             0.971047         0.456053
#     99           0.966349       0.339407             0.988864         0.276100

# %%
import matplotlib.pyplot as plt

model.save("mlp_model_VGG19.h5")

print("Model saved successfully!!")

plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy for VGG19')
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!!

# %%
import os
import pickle
import numpy as np


directory = "C:\\COLON_CANCER DATASET\\PolypDB\\PolypDB_modality_wise\\AUG_PICS\\Model_Test_Feature_PKLs\\VGG19"


modalities = ["bli", "wli", "nbi", "fice", "lci"]


for modality in modalities:
    con_features = []
    count = 0

    for file in os.listdir(directory):
        if modality in file.lower():  
            filename = os.path.join(directory, file)
            count += 1
            with open(filename, 'rb') as f:
                data = pickle.load(f)
                l = len(data)
                con_features.append(data)

    if count > 0:
       
        con_features_arr = np.concatenate(con_features, axis=0)
        con_features_mod = con_features_arr.reshape(count, l)

        
        np.save(f"CONCATENATED_FEATURES_TEST_{modality.upper()}_VGG19.npy", con_features_mod)

        print(f"Saved {modality.upper()} test features successfully! Shape: {con_features_mod.shape}")
    else:
        print(f"No files found for {modality.upper()}.")
# Out:
# Saved BLI test features successfully! Shape: (196, 512)
# Saved WLI test features successfully! Shape: (162, 512)
# Saved NBI test features successfully! Shape: (180, 512)
# Saved FICE test features successfully! Shape: (189, 512)
# Saved LCI test features successfully! Shape: (174, 512)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, log_loss


model = load_model("mlp_model_VGG19.h5")


modalities = ["BLI", "WLI", "FICE", "LCI", "NBI"]
label_order = ["BLI", "FICE", "LCI", "NBI", "WLI"]
label_map = {modality: idx for idx, modality in enumerate(label_order)}


def plot_confusion_matrix(y_true, y_pred, modality):
    cm = confusion_matrix(y_true, y_pred, labels=range(5))
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=label_order, yticklabels=label_order)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix - {modality}")
    plt.show()


l_dense = []


for modality in modalities:
    X_test = np.load(f"CONCATENATED_FEATURES_TEST_{modality}_VGG19.npy")
    
   
    modality_label = label_map[modality]
    y_test = np.full(shape=(len(X_test),), fill_value=modality_label)

    num_classes = 5  
    y_test_one_hot = tf.keras.utils.to_categorical(y_test, num_classes=num_classes)

    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test_one_hot, axis=1)

   
    accuracy = accuracy_score(y_true, y_pred)
    logloss = log_loss(y_test_one_hot, y_pred_probs)
    l_dense.append(logloss)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

   
    print(f"Results for {modality}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")
    print(f"Log Loss: {logloss:.4f}")
    print(f"Unique labels in y_test: {np.unique(y_test)}")
    print("-" * 40)

    
    plot_confusion_matrix(y_true, y_pred, modality)


print(f"Average Log_loss for the VGG19: {sum(l_dense)/5:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Results for BLI:
# Accuracy: 0.9898
# Precision: 1.0000
# Recall: 0.9898
# F1-score: 0.9949
# Log Loss: 0.0448
# Unique labels in y_test: [0]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for WLI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0015
# Unique labels in y_test: [4]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Results for FICE:
# Accuracy: 0.9947
# Precision: 1.0000
# Recall: 0.9947
# F1-score: 0.9973
# Log Loss: 0.0186
# Unique labels in y_test: [1]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Results for LCI:
# Accuracy: 0.9770
# Precision: 1.0000
# Recall: 0.9770
# F1-score: 0.9884
# Log Loss: 0.1002
# Unique labels in y_test: [2]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Results for NBI:
# Accuracy: 0.9778
# Precision: 1.0000
# Recall: 0.9778
# F1-score: 0.9888
# Log Loss: 0.1486
# Unique labels in y_test: [3]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Average Log_loss for the VGG19: 0.0627
