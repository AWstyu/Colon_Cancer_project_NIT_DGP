# %%
import os
os.chdir("C:\\COLON_CANCER DATASET")

# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks, regularizers
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


X_train = np.load("CONCATENATED_FEATURES_TRAIN_InceptionV3.npy")  
y_train = np.load("Training_labels.npy")    
X_val = np.load("CONCATENATED_FEATURES_VALIDATE_InceptionV3.npy")
y_val = np.load("Validation_labels.npy")

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")


num_classes = 5  
y_train = to_categorical(y_train, num_classes=num_classes)
y_val = to_categorical(y_val, num_classes=num_classes)


def build_mlp(input_shape=(2048,), num_classes=5):
    inputs = layers.Input(shape=input_shape)
    x = layers.Dense(1024, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(inputs)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(512, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.6)(x)
    
    x = layers.Dense(256, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.55)(x)
    
    x = layers.Dense(128, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(64, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(32, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.45)(x)

    x = layers.Dense(16, kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization(momentum=0.5)(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.35)(x)
    
    outputs = layers.Dense(num_classes, activation='softmax')(x)  
    
    model = models.Model(inputs, outputs)
    optimizer = optimizers.AdamW(learning_rate=0.01, weight_decay=1e-4, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

if __name__ == "__main__":
    model = build_mlp()
    model.summary()
    
    lr_scheduler = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[lr_scheduler])
    
    
    log_data = []
    for epoch in range(0, len(history.history['accuracy']), 10):
        log_data.append([
            epoch,
            history.history['accuracy'][epoch],
            history.history['loss'][epoch],
            history.history['val_accuracy'][epoch],
            history.history['val_loss'][epoch]
        ])
    if (len(history.history['accuracy']) - 1) % 10 != 0:
        last_epoch = len(history.history['accuracy']) - 1
        log_data.append([
            last_epoch,
            history.history['accuracy'][last_epoch],
            history.history['loss'][last_epoch],
            history.history['val_accuracy'][last_epoch],
            history.history['val_loss'][last_epoch]
        ])
   
    log_df = pd.DataFrame(log_data, columns=['Epoch', 'Training Accuracy', 'Training Loss', 'Validation Accuracy', 'Validation Loss'])
    print(log_df.to_string(index=False))
# Out:
# X_train shape: (3150, 2048), y_train shape: (3150,)
# X_val shape: (449, 2048), y_val shape: (449,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_2 (ReLU)                       │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_3 (ReLU)                       │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_4 (ReLU)                       │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_5 (ReLU)                       │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_6 (ReLU)                       │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 5)                   │              85 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,806,277 (10.71 MB)
#  Trainable params: 2,802,213 (10.69 MB)
#  Non-trainable params: 4,064 (15.88 KB)
# Epoch 1/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.2390 - loss: 2.5772 - val_accuracy: 0.5924 - val_loss: 2.2138 - learning_rate: 0.0100
# Epoch 2/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.4841 - loss: 2.2818 - val_accuracy: 0.6949 - val_loss: 2.0388 - learning_rate: 0.0100
# Epoch 3/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.6056 - loss: 2.3237 - val_accuracy: 0.8062 - val_loss: 2.0300 - learning_rate: 0.0100
# Epoch 4/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7027 - loss: 2.2426 - val_accuracy: 0.8797 - val_loss: 1.9354 - learning_rate: 0.0100
# Epoch 5/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.7290 - loss: 2.3131 - val_accuracy: 0.8619 - val_loss: 2.0930 - learning_rate: 0.0100
# Epoch 6/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.7648 - loss: 2.3170 - val_accuracy: 0.8775 - val_loss: 1.9551 - learning_rate: 0.0100
# Epoch 7/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7860 - loss: 2.4182 - val_accuracy: 0.8575 - val_loss: 2.2091 - learning_rate: 0.0100
# Epoch 8/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7827 - loss: 2.3799 - val_accuracy: 0.8285 - val_loss: 2.3260 - learning_rate: 0.0100
# Epoch 9/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.7887 - loss: 2.4911 - val_accuracy: 0.8129 - val_loss: 2.3024 - learning_rate: 0.0100
# Epoch 10/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8050 - loss: 2.2894 - val_accuracy: 0.9042 - val_loss: 1.6772 - learning_rate: 0.0050
# Epoch 11/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8207 - loss: 1.9361 - val_accuracy: 0.8998 - val_loss: 1.6607 - learning_rate: 0.0050
# Epoch 12/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8291 - loss: 1.8931 - val_accuracy: 0.8864 - val_loss: 1.6489 - learning_rate: 0.0050
# Epoch 13/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8324 - loss: 1.8711 - val_accuracy: 0.8619 - val_loss: 1.8719 - learning_rate: 0.0050
# Epoch 14/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8511 - loss: 1.8883 - val_accuracy: 0.8886 - val_loss: 1.6655 - learning_rate: 0.0050
# Epoch 15/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8567 - loss: 1.7838 - val_accuracy: 0.9154 - val_loss: 1.4294 - learning_rate: 0.0050
# Epoch 16/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8704 - loss: 1.6818 - val_accuracy: 0.9176 - val_loss: 1.4619 - learning_rate: 0.0050
# Epoch 17/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8426 - loss: 1.7217 - val_accuracy: 0.8931 - val_loss: 1.6024 - learning_rate: 0.0050
# Epoch 18/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8452 - loss: 1.8323 - val_accuracy: 0.8976 - val_loss: 1.5874 - learning_rate: 0.0050
# Epoch 19/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8574 - loss: 1.7445 - val_accuracy: 0.8597 - val_loss: 1.6942 - learning_rate: 0.0050
# Epoch 20/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8531 - loss: 1.6971 - val_accuracy: 0.8218 - val_loss: 1.7784 - learning_rate: 0.0050
# Epoch 21/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8700 - loss: 1.7089 - val_accuracy: 0.9131 - val_loss: 1.4233 - learning_rate: 0.0025
# Epoch 22/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8826 - loss: 1.5124 - val_accuracy: 0.8731 - val_loss: 1.4346 - learning_rate: 0.0025
# Epoch 23/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8886 - loss: 1.3922 - val_accuracy: 0.9465 - val_loss: 1.1312 - learning_rate: 0.0025
# Epoch 24/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8949 - loss: 1.3141 - val_accuracy: 0.8686 - val_loss: 1.4419 - learning_rate: 0.0025
# Epoch 25/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8796 - loss: 1.3481 - val_accuracy: 0.9131 - val_loss: 1.2817 - learning_rate: 0.0025
# Epoch 26/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8787 - loss: 1.3701 - val_accuracy: 0.8931 - val_loss: 1.2312 - learning_rate: 0.0025
# Epoch 27/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8996 - loss: 1.2591 - val_accuracy: 0.9131 - val_loss: 1.0826 - learning_rate: 0.0025
# Epoch 28/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9005 - loss: 1.2160 - val_accuracy: 0.9020 - val_loss: 1.2648 - learning_rate: 0.0025
# Epoch 29/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9017 - loss: 1.2287 - val_accuracy: 0.9198 - val_loss: 1.1185 - learning_rate: 0.0025
# Epoch 30/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9049 - loss: 1.1882 - val_accuracy: 0.9109 - val_loss: 1.0942 - learning_rate: 0.0025
# Epoch 31/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9035 - loss: 1.1511 - val_accuracy: 0.9131 - val_loss: 1.1291 - learning_rate: 0.0025
# Epoch 32/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9012 - loss: 1.1469 - val_accuracy: 0.9265 - val_loss: 1.0777 - learning_rate: 0.0025
# Epoch 33/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9142 - loss: 1.1417 - val_accuracy: 0.9131 - val_loss: 1.1328 - learning_rate: 0.0025
# Epoch 34/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8958 - loss: 1.2331 - val_accuracy: 0.8797 - val_loss: 1.2255 - learning_rate: 0.0025
# Epoch 35/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9138 - loss: 1.1413 - val_accuracy: 0.9376 - val_loss: 1.0204 - learning_rate: 0.0025
# Epoch 36/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9102 - loss: 1.1357 - val_accuracy: 0.9243 - val_loss: 1.0380 - learning_rate: 0.0025
# Epoch 37/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9007 - loss: 1.1677 - val_accuracy: 0.8686 - val_loss: 1.3870 - learning_rate: 0.0025
# Epoch 38/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9023 - loss: 1.1918 - val_accuracy: 0.8820 - val_loss: 1.3496 - learning_rate: 0.0025
# Epoch 39/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9048 - loss: 1.1650 - val_accuracy: 0.9310 - val_loss: 1.0330 - learning_rate: 0.0025
# Epoch 40/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9041 - loss: 1.1477 - val_accuracy: 0.9243 - val_loss: 1.0517 - learning_rate: 0.0025
# Epoch 41/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9146 - loss: 1.1189 - val_accuracy: 0.9176 - val_loss: 1.0433 - learning_rate: 0.0012
# Epoch 42/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9179 - loss: 1.0546 - val_accuracy: 0.8797 - val_loss: 1.2338 - learning_rate: 0.0012
# Epoch 43/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9226 - loss: 1.0087 - val_accuracy: 0.9443 - val_loss: 0.9196 - learning_rate: 0.0012
# Epoch 44/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9301 - loss: 0.9714 - val_accuracy: 0.9599 - val_loss: 0.8397 - learning_rate: 0.0012
# Epoch 45/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9162 - loss: 0.9805 - val_accuracy: 0.9688 - val_loss: 0.7718 - learning_rate: 0.0012
# Epoch 46/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9282 - loss: 0.9088 - val_accuracy: 0.9220 - val_loss: 0.8872 - learning_rate: 0.0012
# Epoch 47/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9399 - loss: 0.8656 - val_accuracy: 0.9220 - val_loss: 0.9086 - learning_rate: 0.0012
# Epoch 48/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9463 - loss: 0.8447 - val_accuracy: 0.9555 - val_loss: 0.7736 - learning_rate: 0.0012
# Epoch 49/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9475 - loss: 0.8177 - val_accuracy: 0.9421 - val_loss: 0.8695 - learning_rate: 0.0012
# Epoch 50/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9352 - loss: 0.8260 - val_accuracy: 0.9555 - val_loss: 0.7402 - learning_rate: 0.0012
# Epoch 51/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9354 - loss: 0.8312 - val_accuracy: 0.9688 - val_loss: 0.6751 - learning_rate: 0.0012
# Epoch 52/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9440 - loss: 0.7844 - val_accuracy: 0.9510 - val_loss: 0.7475 - learning_rate: 0.0012
# Epoch 53/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9414 - loss: 0.7908 - val_accuracy: 0.9599 - val_loss: 0.7020 - learning_rate: 0.0012
# Epoch 54/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9465 - loss: 0.7544 - val_accuracy: 0.9243 - val_loss: 0.9000 - learning_rate: 0.0012
# Epoch 55/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9493 - loss: 0.7733 - val_accuracy: 0.9599 - val_loss: 0.6464 - learning_rate: 0.0012
# Epoch 56/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9435 - loss: 0.7550 - val_accuracy: 0.9599 - val_loss: 0.6703 - learning_rate: 0.0012
# Epoch 57/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9362 - loss: 0.7566 - val_accuracy: 0.9443 - val_loss: 0.7954 - learning_rate: 0.0012
# Epoch 58/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9283 - loss: 0.8035 - val_accuracy: 0.9577 - val_loss: 0.6785 - learning_rate: 0.0012
# Epoch 59/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9428 - loss: 0.7571 - val_accuracy: 0.9555 - val_loss: 0.6830 - learning_rate: 0.0012
# Epoch 60/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9407 - loss: 0.7381 - val_accuracy: 0.9354 - val_loss: 0.7076 - learning_rate: 0.0012
# Epoch 61/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9402 - loss: 0.7428 - val_accuracy: 0.9421 - val_loss: 0.7587 - learning_rate: 6.2500e-04
# Epoch 62/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9460 - loss: 0.6931 - val_accuracy: 0.9666 - val_loss: 0.6329 - learning_rate: 6.2500e-04
# Epoch 63/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9470 - loss: 0.6848 - val_accuracy: 0.9510 - val_loss: 0.6758 - learning_rate: 6.2500e-04
# Epoch 64/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9501 - loss: 0.6938 - val_accuracy: 0.9176 - val_loss: 0.8158 - learning_rate: 6.2500e-04
# Epoch 65/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9548 - loss: 0.6301 - val_accuracy: 0.9621 - val_loss: 0.6201 - learning_rate: 6.2500e-04
# Epoch 66/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9612 - loss: 0.6238 - val_accuracy: 0.9131 - val_loss: 0.9638 - learning_rate: 6.2500e-04
# Epoch 67/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9528 - loss: 0.6011 - val_accuracy: 0.9443 - val_loss: 0.7490 - learning_rate: 6.2500e-04
# Epoch 68/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9610 - loss: 0.5805 - val_accuracy: 0.9688 - val_loss: 0.5550 - learning_rate: 6.2500e-04
# Epoch 69/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9571 - loss: 0.5930 - val_accuracy: 0.9310 - val_loss: 0.7885 - learning_rate: 6.2500e-04
# Epoch 70/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9568 - loss: 0.6003 - val_accuracy: 0.9688 - val_loss: 0.5504 - learning_rate: 6.2500e-04
# Epoch 71/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9661 - loss: 0.5607 - val_accuracy: 0.9710 - val_loss: 0.5304 - learning_rate: 6.2500e-04
# Epoch 72/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9455 - loss: 0.6095 - val_accuracy: 0.9577 - val_loss: 0.5501 - learning_rate: 6.2500e-04
# Epoch 73/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9561 - loss: 0.5437 - val_accuracy: 0.9332 - val_loss: 0.6517 - learning_rate: 6.2500e-04
# Epoch 74/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9554 - loss: 0.5760 - val_accuracy: 0.9599 - val_loss: 0.5604 - learning_rate: 6.2500e-04
# Epoch 75/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9609 - loss: 0.5758 - val_accuracy: 0.9310 - val_loss: 0.6713 - learning_rate: 6.2500e-04
# Epoch 76/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9535 - loss: 0.5626 - val_accuracy: 0.9399 - val_loss: 0.6842 - learning_rate: 6.2500e-04
# Epoch 77/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9577 - loss: 0.5316 - val_accuracy: 0.9621 - val_loss: 0.5085 - learning_rate: 3.1250e-04
# Epoch 78/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9570 - loss: 0.5433 - val_accuracy: 0.9844 - val_loss: 0.4470 - learning_rate: 3.1250e-04
# Epoch 79/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9650 - loss: 0.4921 - val_accuracy: 0.9644 - val_loss: 0.5310 - learning_rate: 3.1250e-04
# Epoch 80/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9615 - loss: 0.5061 - val_accuracy: 0.9733 - val_loss: 0.4657 - learning_rate: 3.1250e-04
# Epoch 81/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9573 - loss: 0.5181 - val_accuracy: 0.9666 - val_loss: 0.5234 - learning_rate: 3.1250e-04
# Epoch 82/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9688 - loss: 0.4781 - val_accuracy: 0.9488 - val_loss: 0.6389 - learning_rate: 3.1250e-04
# Epoch 83/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9592 - loss: 0.5223 - val_accuracy: 0.9376 - val_loss: 0.5980 - learning_rate: 3.1250e-04
# Epoch 84/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9724 - loss: 0.4641 - val_accuracy: 0.9599 - val_loss: 0.4963 - learning_rate: 1.5625e-04
# Epoch 85/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9660 - loss: 0.4882 - val_accuracy: 0.9532 - val_loss: 0.5705 - learning_rate: 1.5625e-04
# Epoch 86/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9654 - loss: 0.4889 - val_accuracy: 0.9733 - val_loss: 0.4618 - learning_rate: 1.5625e-04
# Epoch 87/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9712 - loss: 0.4539 - val_accuracy: 0.9621 - val_loss: 0.5109 - learning_rate: 1.5625e-04
# Epoch 88/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9606 - loss: 0.4835 - val_accuracy: 0.9710 - val_loss: 0.4468 - learning_rate: 1.5625e-04
# Epoch 89/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9710 - loss: 0.4387 - val_accuracy: 0.9532 - val_loss: 0.5326 - learning_rate: 1.5625e-04
# Epoch 90/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9682 - loss: 0.4580 - val_accuracy: 0.9577 - val_loss: 0.5883 - learning_rate: 1.5625e-04
# Epoch 91/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9726 - loss: 0.4287 - val_accuracy: 0.9644 - val_loss: 0.4740 - learning_rate: 1.5625e-04
# Epoch 92/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9676 - loss: 0.4683 - val_accuracy: 0.9666 - val_loss: 0.5176 - learning_rate: 1.5625e-04
# Epoch 93/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9624 - loss: 0.4607 - val_accuracy: 0.9621 - val_loss: 0.5520 - learning_rate: 1.5625e-04
# Epoch 94/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9646 - loss: 0.4548 - val_accuracy: 0.9710 - val_loss: 0.4464 - learning_rate: 7.8125e-05
# Epoch 95/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9745 - loss: 0.4407 - val_accuracy: 0.9688 - val_loss: 0.4742 - learning_rate: 7.8125e-05
# Epoch 96/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9742 - loss: 0.4149 - val_accuracy: 0.9844 - val_loss: 0.4106 - learning_rate: 7.8125e-05
# Epoch 97/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9575 - loss: 0.4703 - val_accuracy: 0.9465 - val_loss: 0.5998 - learning_rate: 7.8125e-05
# Epoch 98/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9672 - loss: 0.5043 - val_accuracy: 0.9710 - val_loss: 0.4353 - learning_rate: 7.8125e-05
# Epoch 99/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9634 - loss: 0.4267 - val_accuracy: 0.9577 - val_loss: 0.5725 - learning_rate: 7.8125e-05
# Epoch 100/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9677 - loss: 0.4258 - val_accuracy: 0.9465 - val_loss: 0.5582 - learning_rate: 7.8125e-05
#  Epoch  Training Accuracy  Training Loss  Validation Accuracy  Validation Loss
#      0           0.301270       2.647520             0.592428         2.213821
#     10           0.822540       1.948205             0.899777         1.660683
#     20           0.863175       1.676308             0.913140         1.423266
#     30           0.901905       1.162666             0.913140         1.129132
#     40           0.914921       1.103740             0.917595         1.043297
#     50           0.933651       0.831639             0.968820         0.675063
#     60           0.938413       0.739438             0.942094         0.758674
#     70           0.964127       0.555841             0.971047         0.530401
#     80           0.958413       0.513594             0.966592         0.523358
#     90           0.968254       0.447663             0.964365         0.473953
#     99           0.965714       0.437520             0.946548         0.558230

# %%
import matplotlib.pyplot as plt

model.save("mlp_model_InceptionV3.h5")

print("Model saved successfully!!")

plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy for InceptionV3')
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!!

# %%
import os
import pickle
import numpy as np


directory = "C:\\COLON_CANCER DATASET\\PolypDB\\PolypDB_modality_wise\\AUG_PICS\\Model_Test_Feature_PKLs\\InceptionV3"


modalities = ["bli", "wli", "nbi", "fice", "lci"]


for modality in modalities:
    con_features = []
    count = 0

    for file in os.listdir(directory):
        if modality in file.lower():  
            filename = os.path.join(directory, file)
            count += 1
            with open(filename, 'rb') as f:
                data = pickle.load(f)
                l = len(data)
                con_features.append(data)

    if count > 0:
       
        con_features_arr = np.concatenate(con_features, axis=0)
        con_features_mod = con_features_arr.reshape(count, l)

        
        np.save(f"CONCATENATED_FEATURES_TEST_{modality.upper()}_InceptionV3.npy", con_features_mod)

        print(f"Saved {modality.upper()} test features successfully! Shape: {con_features_mod.shape}")
    else:
        print(f"No files found for {modality.upper()}.")
# Out:
# Saved BLI test features successfully! Shape: (196, 2048)
# Saved WLI test features successfully! Shape: (162, 2048)
# Saved NBI test features successfully! Shape: (180, 2048)
# Saved FICE test features successfully! Shape: (189, 2048)
# Saved LCI test features successfully! Shape: (174, 2048)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, log_loss


model = load_model("mlp_model_InceptionResNetV2.h5")


modalities = ["BLI", "WLI", "FICE", "LCI", "NBI"]
label_order = ["BLI", "FICE", "LCI", "NBI", "WLI"]
label_map = {modality: idx for idx, modality in enumerate(label_order)}


def plot_confusion_matrix(y_true, y_pred, modality):
    cm = confusion_matrix(y_true, y_pred, labels=range(5))
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=label_order, yticklabels=label_order)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix - {modality}")
    plt.show()


l_dense = []


for modality in modalities:
    X_test = np.load(f"CONCATENATED_FEATURES_TEST_{modality}_InceptionResNetV2.npy")
    
   
    modality_label = label_map[modality]
    y_test = np.full(shape=(len(X_test),), fill_value=modality_label)

    num_classes = 5  
    y_test_one_hot = tf.keras.utils.to_categorical(y_test, num_classes=num_classes)

    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test_one_hot, axis=1)

   
    accuracy = accuracy_score(y_true, y_pred)
    logloss = log_loss(y_test_one_hot, y_pred_probs)
    l_dense.append(logloss)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

   
    print(f"Results for {modality}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")
    print(f"Log Loss: {logloss:.4f}")
    print(f"Unique labels in y_test: {np.unique(y_test)}")
    print("-" * 40)

    
    plot_confusion_matrix(y_true, y_pred, modality)


print(f"Average Log_loss for the InceptionResnetV2: {sum(l_dense)/5:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Results for BLI:
# Accuracy: 0.9490
# Precision: 1.0000
# Recall: 0.9490
# F1-score: 0.9738
# Log Loss: 0.2496
# Unique labels in y_test: [0]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Results for WLI:
# Accuracy: 0.9877
# Precision: 1.0000
# Recall: 0.9877
# F1-score: 0.9938
# Log Loss: 0.0949
# Unique labels in y_test: [4]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for FICE:
# Accuracy: 0.9841
# Precision: 1.0000
# Recall: 0.9841
# F1-score: 0.9920
# Log Loss: 0.0720
# Unique labels in y_test: [1]
# ----------------------------------------
# C:\Users\anubh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for LCI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0004
# Unique labels in y_test: [2]
# ----------------------------------------
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Results for NBI:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# Log Loss: 0.0003
# Unique labels in y_test: [3]
# ----------------------------------------
# Average Log_loss for the InceptionResnetV2: 0.0834
